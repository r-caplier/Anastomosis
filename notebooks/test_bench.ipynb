# %%
import requests
import json

import os
import time
import pandas as pd

from tqdm.auto import tqdm

from termcolor import colored

# %%
API_URL = "https://uts-ws.nlm.nih.gov/rest"
KEY = "e9831397-cd97-4172-b34e-6e1b1b6d125d"

# %%
ROOT_PATH = os.path.dirname(os.getcwd())

DATA_CLEAN_PATH = os.path.join(ROOT_PATH, "data", "data_clean")
ENTITIES_PATH = os.path.join(ROOT_PATH, "data", "entities")

PAGE_SIZE = 50
NUM_MATCHES = 5
unsuspected
filename = "21616724.txt"

# %%
with open(os.path.join(DATA_CLEAN_PATH, filename), "r") as f:
    text = f.read()

with open(os.path.join(ENTITIES_PATH, filename.split(".")[0] + ".csv"), "r") as f:
    entities_df = pd.read_csv(f)

# %%
def get_semanticType(word):
    
    word = word.strip().lower()
    
    def get_search_url(term):
        return API_URL + f"/search/current/?apiKey={KEY}&string={term}&pageSize={PAGE_SIZE}"
    
    def add_api_key(url):
        return url + f"?apiKey={KEY}"
    
    with requests.get(get_search_url(word)) as r:
        results = json.loads(r.content)["result"]["results"]
        all_types = {}
        for cui in results:
            if cui["name"].strip().lower() == word:
                with requests.get(add_api_key(cui["uri"])) as r_word:
                    s_type = []
                    for s_t in json.loads(r_word.content)["result"]["semanticTypes"]:
                        return s_t["name"]
            else:
                with requests.get(add_api_key(cui["uri"])) as r_word:
                    s_type = []
                    for s_t in json.loads(r_word.content)["result"]["semanticTypes"]:
                        name = s_t["name"]
                        if name not in all_types.keys():
                            all_types[name] = 1
                        else:
                            all_types[name] += 1
        
        if len(all_types) != 0:                   
            return max(all_types, key=all_types.get)
        else:
            return "Unknown"

# %%
def get_color_map(entities_df):

    colors = ["red", "blue", "green", "yellow", "magenta", "cyan", "grey", "white"]

    types_to_color = {}
    cnt = 0
    for type_ent in list(entities_df["Type"].value_counts().index):
        try:
            types_to_color[type_ent] = colors[cnt]
        except:
            types_to_color[type_ent] = None
        cnt += 1

    return types_to_color

# %%
color_map = get_color_map(entities_df)
colored_text = ""
last_end = 0

for i in range(len(entities_df)):
    start = entities_df.iloc[i]["StartChar"]
    end = entities_df.iloc[i]["EndChar"]
    e_type = entities_df.iloc[i]["Type"]
    word = entities_df.iloc[i]["Word"].strip().lower()
    if last_end <= start:
        if e_type == "ENTITY":
            if word in entity_types.keys():
                colored_text += text[last_end:start] + colored(text[start:end], color_map[e_type]) + "(: " + entity_types[word] + ")"
            else:
                colored_text += text[last_end:start] + colored(text[start:end], color_map[e_type]) + "(: Error!)"
        else:
            colored_text += text[last_end:start] + colored(text[start:end], color_map[e_type])
        last_end = end
    elif last_end > start and last_end < end:
        colored_text += colored(text[last_end:end], color_map[e_type])
        last_end = end
if last_end != len(text):
    colored_text += text[last_end:]

# %%
def display_likely_types(entities):
    
    def get_search_url(term):
        return API_URL + f"/search/current/?apiKey={KEY}&string={term}&pageSize={PAGE_SIZE}"
    
    def add_api_key(url):
        return url + f"?apiKey={KEY}"
    
    def get_type(word):
        
        word = word.strip().lower()
         
        with requests.get(get_search_url(word)) as r:
            results = json.loads(r.content)["result"]["results"]
            all_types = {}
            
            for cui in results:
                # Direct match (first of the list usually, so this won't run forever)
                if cui["name"].strip().lower() == word:
                    with requests.get(add_api_key(cui["uri"])) as r_word:
                        s_type = []
                        for s_t in json.loads(r_word.content)["result"]["semanticTypes"]:
                            return s_t["name"]
                # No direct match. Runs through the list of matches and gathers the semantic types found       
                else:
                    with requests.get(add_api_key(cui["uri"])) as r_word:
                        s_type = []
                        for s_t in json.loads(r_word.content)["result"]["semanticTypes"]:
                            name = s_t["name"]
                            if name not in all_types.keys():
                                all_types[name] = 1
                            else:
                                all_types[name] += 1
        
            if len(all_types) != 0:                   
                return [(k, all_types[k]) for k in sorted(all_types, key=all_types.get, reverse=True)[:NUM_MATCHES]]
            else:
                return "Unknown"
        
    entity_types = {}
    entity_counts = {}
    
    for word in tqdm(entities_df.loc[entities_df["Type"] == "ENTITY"]["Word"]):
        
        word_s = word.strip().lower()
        
        if word_s not in entity_types.keys():
            count = 0
            e_type = None
            while e_type == None and count < 30:
                try:
                    e_type = get_type(word_s)
                except:
                    print(f"Connection error, retrying... ({count})")
                count += 1
                time.sleep(1)
            entity_types[word_s] = e_type
            
        else:
            e_type = entity_types[word_s]
            
        if type(e_type) is str:
            if e_type not in entity_counts.keys():
                entity_counts[e_type] = 1
            else:
                entity_counts[e_type] += 1
            print(f"{word}: {e_type}")
                
        else:
            disp = f"{word}: "
            for elem in e_type:
                disp += f"{elem} / "
            print(disp[: -3])
    
    return entity_types

# %%
entity_types = display_likely_types(entities_df)
# Out:
#   0%|          | 0/283 [00:00<?, ?it/s]
# Laparoscopic sleeve gastrectomy: Therapeutic or Preventive Procedure
# Connection error, retrying (0)...
# procedure: ('Therapeutic or Preventive Procedure', 34) / ('Diagnostic Procedure', 11) / ('Laboratory Procedure', 4) / ('Health Care Activity', 1)
# surgical management: Health Care Activity
# morbid obesity: Disease or Syndrome
# postoperative gastric leak: Unknown
# procedure: ('Therapeutic or Preventive Procedure', 34) / ('Diagnostic Procedure', 11) / ('Laboratory Procedure', 4) / ('Health Care Activity', 1)
# complication: Pathologic Function
# incidence: Quantitative Concept
# leak: ('Finding', 29) / ('Disease or Syndrome', 12) / ('Pathologic Function', 7) / ('Injury or Poisoning', 2)
# leak: ('Finding', 29) / ('Disease or Syndrome', 12) / ('Pathologic Function', 7) / ('Injury or Poisoning', 2)
# upper part: ('Body Location or Region', 19) / ('Body Part, Organ, or Organ Component', 14) / ('Congenital Abnormality', 4) / ('Injury or Poisoning', 4) / ('Sign or Symptom', 4)
# staple line: ('Therapeutic or Preventive Procedure', 2) / ('Medical Device', 1)
# gastroesophageal junction: ('Neoplastic Process', 35) / ('Diagnostic Procedure', 5) / ('Therapeutic or Preventive Procedure', 4) / ('Disease or Syndrome', 3) / ('Body Space or Junction', 1)
# source: Finding
# morbidity: ('Finding', 16) / ('Injury or Poisoning', 16) / ('Disease or Syndrome', 7) / ('Intellectual Product', 4) / ('Pathologic Function', 3)
# fatal: Qualitative Concept
# Intraoperative tests: Unknown
# methylene blue dye test: Unknown
# air leak test: Unknown
# endoscopy: ('Diagnostic Procedure', 40) / ('Therapeutic or Preventive Procedure', 5) / ('Health Care Activity', 4) / ('Qualitative Concept', 1)
# diagnose: ('Finding', 16) / ('Diagnostic Procedure', 7) / ('Disease or Syndrome', 5) / ('Clinical Attribute', 4) / ('Health Care Activity', 4)
# staple line: ('Therapeutic or Preventive Procedure', 2) / ('Medical Device', 1)
# disruption: Functional Concept
# tests: ('Diagnostic Procedure', 25) / ('Laboratory Procedure', 22) / ('Intellectual Product', 1) / ('Finding', 1) / ('Medical Device', 1)
# findings: ('Finding', 40) / ('Disease or Syndrome', 2) / ('Laboratory or Test Result', 2) / ('Functional Concept', 1) / ('Congenital Abnormality', 1)
# positive: Finding
# negative test: ('Laboratory or Test Result', 34) / ('Finding', 9) / ('Diagnostic Procedure', 5) / ('Sign or Symptom', 2)
# leak: ('Finding', 29) / ('Disease or Syndrome', 12) / ('Pathologic Function', 7) / ('Injury or Poisoning', 2)
# postoperative: ('Pathologic Function', 20) / ('Disease or Syndrome', 10) / ('Sign or Symptom', 5) / ('Mental or Behavioral Dysfunction', 4) / ('Therapeutic or Preventive Procedure', 3)
# period: ('Temporal Concept', 29) / ('Finding', 6) / ('Disease or Syndrome', 4) / ('Pathologic Function', 4) / ('Quantitative Concept', 2)
# routine: Qualitative Concept
# practice: ('Therapeutic or Preventive Procedure', 13) / ('Biomedical Occupation or Discipline', 9) / ('Health Care Related Organization', 6) / ('Finding', 5) / ('Health Care Activity', 5)
# intraoperative leak test: Unknown
# case: ('Intellectual Product', 19) / ('Finding', 7) / ('Health Care Activity', 5) / ('Clinical Attribute', 4) / ('Functional Concept', 3)
# laparoscopic sleeve gastrectomy: Therapeutic or Preventive Procedure
# positive: Finding
# intraoperative: Temporal Concept
# air leak test: Unknown
# air leak: ('Disease or Syndrome', 11) / ('Health Care Activity', 10) / ('Finding', 6) / ('Diagnostic Procedure', 6) / ('Therapeutic or Preventive Procedure', 3)
# staple line: ('Therapeutic or Preventive Procedure', 2) / ('Medical Device', 1)
# anterior gastric wall: ('Body Part, Organ, or Organ Component', 4) / ('Body Location or Region', 1)
# routine: Qualitative Concept
# practice: ('Therapeutic or Preventive Procedure', 13) / ('Biomedical Occupation or Discipline', 9) / ('Health Care Related Organization', 6) / ('Finding', 5) / ('Health Care Activity', 5)
# intraoperative leak test: Unknown
# Connection error, retrying (0)...
# Connection error, retrying (1)...
# prevented: ('Finding', 12) / ('Intellectual Product', 4) / ('Clinical Attribute', 2) / ('Health Care Activity', 2) / ('Therapeutic or Preventive Procedure', 1)
# postoperative: ('Pathologic Function', 20) / ('Disease or Syndrome', 10) / ('Sign or Symptom', 5) / ('Mental or Behavioral Dysfunction', 4) / ('Therapeutic or Preventive Procedure', 3)
# consequences: ('Finding', 27) / ('Therapeutic or Preventive Procedure', 8) / ('Health Care Activity', 4) / ('Disease or Syndrome', 2) / ('Clinical Attribute', 2)
# case: ('Intellectual Product', 19) / ('Finding', 7) / ('Health Care Activity', 5) / ('Clinical Attribute', 4) / ('Functional Concept', 3)
# missed: ('Finding', 22) / ('Therapeutic or Preventive Procedure', 8) / ('Disease or Syndrome', 4) / ('Sign or Symptom', 3) / ('Intellectual Product', 3)
# injury: ('Injury or Poisoning', 47) / ('Finding', 2) / ('Disease or Syndrome', 1)
# report: ('Intellectual Product', 41) / ('Health Care Activity', 4) / ('Research Activity', 2) / ('Diagnostic Procedure', 1) / ('Finding', 1)
# gastric leak: ('Finding', 7)
# site: ('Disease or Syndrome', 21) / ('Neoplastic Process', 19) / ('Pathologic Function', 7) / ('Sign or Symptom', 2) / ('Injury or Poisoning', 1)
# staple line: ('Therapeutic or Preventive Procedure', 2) / ('Medical Device', 1)
# intraoperative: Temporal Concept
# patient: ('Health Care Activity', 20) / ('Finding', 8) / ('Therapeutic or Preventive Procedure', 8) / ('Intellectual Product', 3) / ('Individual Behavior', 2)
# woman: Population Group
# body mass index: Clinical Attribute
# co-morbidities: ('Intellectual Product', 1) / ('Clinical Attribute', 1)
# type 2 diabetes mellitus: ('Disease or Syndrome', 46) / ('Finding', 3) / ('Health Care Activity', 1)
# Connection error, retrying (0)...
# hypertension: ('Disease or Syndrome', 38) / ('Finding', 5) / ('Pathologic Function', 3) / ('Health Care Activity', 2) / ('Mental Process', 1)
# laparoscopic sleeve gastrectomy: Therapeutic or Preventive Procedure
# ports: ('Therapeutic or Preventive Procedure', 31) / ('Medical Device', 11) / ('Clinical Attribute', 2) / ('Health Care Activity', 2) / ('Manufactured Object', 1)
# omentum: Body Part, Organ, or Organ Component
# greater: Quantitative Concept
# Connection error, retrying (0)...
# curvature: ('Finding', 10) / ('Acquired Abnormality', 6) / ('Body Location or Region', 5) / ('Spatial Concept', 4) / ('Disease or Syndrome', 4)
# pylorus: Body Part, Organ, or Organ Component
# gastroesophageal junction: ('Neoplastic Process', 35) / ('Diagnostic Procedure', 5) / ('Therapeutic or Preventive Procedure', 4) / ('Disease or Syndrome', 3) / ('Body Space or Junction', 1)
# gastric sleeve: Medical Device
# calibration tube: ('Medical Device', 2)
# sequential: Qualitative Concept
# firings: Unknown
# Endoscopic linear cutter: Unknown
# Echelon: ('Finding', 1) / ('Clinical Attribute', 1) / ('Qualitative Concept', 1)
# blue cartridges: Unknown
# longitudinal gastrectomy: ('Therapeutic or Preventive Procedure', 3)
# buttressing material: Unknown
# sutures: ('Finding', 26) / ('Medical Device', 9) / ('Body Space or Junction', 5) / ('Therapeutic or Preventive Procedure', 4) / ('Disease or Syndrome', 1)
# staple line: ('Therapeutic or Preventive Procedure', 2) / ('Medical Device', 1)
# reinforcement: ('Therapeutic or Preventive Procedure', 20) / ('Finding', 13) / ('Health Care Activity', 6) / ('Mental Process', 3) / ('Social Behavior', 3)
# procedure: ('Therapeutic or Preventive Procedure', 34) / ('Diagnostic Procedure', 11) / ('Laboratory Procedure', 4) / ('Health Care Activity', 1)
# uneventful: Finding
# intraoperative leak test: Unknown
# air insufflation: ('Diagnostic Procedure', 3)
# nasogastric tube: Medical Device
# leak: ('Finding', 29) / ('Disease or Syndrome', 12) / ('Pathologic Function', 7) / ('Injury or Poisoning', 2)
# Connection error, retrying (0)...
# detected: ('Finding', 33) / ('Laboratory or Test Result', 15) / ('Intellectual Product', 2)
# insufflation: Health Care Activity
# air: Pharmacologic Substance
# insufflating: ('Medical Device', 1)
# air: Pharmacologic Substance
# air bubbles: ('Therapeutic or Preventive Procedure', 5) / ('Health Care Activity', 3) / ('Substance', 1) / ('Finding', 1)
# upper part: ('Body Location or Region', 19) / ('Body Part, Organ, or Organ Component', 14) / ('Congenital Abnormality', 4) / ('Injury or Poisoning', 4) / ('Sign or Symptom', 4)
# stomach tube: ('Therapeutic or Preventive Procedure', 29) / ('Medical Device', 4) / ('Diagnostic Procedure', 3) / ('Health Care Activity', 3) / ('Laboratory Procedure', 3)
# figure-of-8 suture: Unknown
# staple line: ('Therapeutic or Preventive Procedure', 2) / ('Medical Device', 1)
# air: Pharmacologic Substance
# leaking: Functional Concept
# repeat leak test: Unknown
# persistent: Temporal Concept
# air leak: ('Disease or Syndrome', 11) / ('Health Care Activity', 10) / ('Finding', 6) / ('Diagnostic Procedure', 6) / ('Therapeutic or Preventive Procedure', 3)
# Connection error, retrying (0)...
# region: ('Body Location or Region', 29) / ('Body Part, Organ, or Organ Component', 12) / ('Sign or Symptom', 3) / ('Disease or Syndrome', 2) / ('Injury or Poisoning', 2)
# region: ('Body Location or Region', 29) / ('Body Part, Organ, or Organ Component', 12) / ('Sign or Symptom', 3) / ('Disease or Syndrome', 2) / ('Injury or Poisoning', 2)
# evaluated: ('Finding', 19) / ('Health Care Activity', 5) / ('Therapeutic or Preventive Procedure', 5) / ('Functional Concept', 5) / ('Intellectual Product', 5)
# area of: ('Body Location or Region', 21) / ('Body Part, Organ, or Organ Component', 21) / ('Quantitative Concept', 2) / ('Disease or Syndrome', 1) / ('Body Space or Junction', 1)
# bruising: ('Finding', 27) / ('Injury or Poisoning', 11) / ('Sign or Symptom', 6) / ('Pathologic Function', 3) / ('Disease or Syndrome', 3)
# anterior wall: Spatial Concept
# stomach: Body Part, Organ, or Organ Component
# air: Pharmacologic Substance
# leaking: Functional Concept
# rent: Idea or Concept
# interrupted: Qualitative Concept
# polydiaxonone sutures: Unknown
# air leak test: Unknown
# negative: Finding
# upper gastrointestinal contrast study: ('Diagnostic Procedure', 2)
# postoperative: ('Pathologic Function', 20) / ('Disease or Syndrome', 10) / ('Sign or Symptom', 5) / ('Mental or Behavioral Dysfunction', 4) / ('Therapeutic or Preventive Procedure', 3)
# day: Temporal Concept
# normal: Qualitative Concept
# patient: ('Health Care Activity', 20) / ('Finding', 8) / ('Therapeutic or Preventive Procedure', 8) / ('Intellectual Product', 3) / ('Individual Behavior', 2)
# Connection error, retrying (0)...
# uneventful recovery: ('Idea or Concept', 1)
# Intraoperative: Temporal Concept
# air leak test: Unknown
# air: Pharmacologic Substance
# bubble: ('Medical Device', 13) / ('Finding', 6) / ('Therapeutic or Preventive Procedure', 5) / ('Manufactured Object', 5) / ('Food', 3)
# upper part of sleeve: Unknown
# Upper end of sleeve: Unknown
# bruise: ('Injury or Poisoning', 24) / ('Finding', 9) / ('Pathologic Function', 6) / ('Intellectual Product', 2) / ('Pharmacologic Substance', 2)
# ecchymosis: Pathologic Function
# anterior wall of stomach: ('Body Part, Organ, or Organ Component', 11) / ('Body Location or Region', 9) / ('Neoplastic Process', 2)
# bruising: ('Finding', 27) / ('Injury or Poisoning', 11) / ('Sign or Symptom', 6) / ('Pathologic Function', 3) / ('Disease or Syndrome', 3)
# ecchymosis: Pathologic Function
# evaluation: Health Care Activity
# inadvertent: ('Injury or Poisoning', 7) / ('Health Care Activity', 4) / ('Pathologic Function', 4) / ('Finding', 2) / ('Therapeutic or Preventive Procedure', 2)
# perforation: ('Disease or Syndrome', 18) / ('Finding', 13) / ('Injury or Poisoning', 9) / ('Pathologic Function', 5) / ('Acquired Abnormality', 2)
# Sleeve gastrectomy: Therapeutic or Preventive Procedure
# long staple line: Unknown
# long staple line: Unknown
# leak: ('Finding', 29) / ('Disease or Syndrome', 12) / ('Pathologic Function', 7) / ('Injury or Poisoning', 2)
# postoperative: ('Pathologic Function', 20) / ('Disease or Syndrome', 10) / ('Sign or Symptom', 5) / ('Mental or Behavioral Dysfunction', 4) / ('Therapeutic or Preventive Procedure', 3)
# period: ('Temporal Concept', 29) / ('Finding', 6) / ('Disease or Syndrome', 4) / ('Pathologic Function', 4) / ('Quantitative Concept', 2)
# morbidity: ('Finding', 16) / ('Injury or Poisoning', 16) / ('Disease or Syndrome', 7) / ('Intellectual Product', 4) / ('Pathologic Function', 3)
# mortality: ('Quantitative Concept', 21) / ('Finding', 15) / ('Intellectual Product', 5) / ('Injury or Poisoning', 4) / ('Virus', 2)
# methods: Functional Concept
# intraoperative testing: ('Diagnostic Procedure', 3)
# Connection error, retrying (0)...
# leaks: ('Health Care Activity', 5) / ('Pathologic Function', 4) / ('Finding', 3) / ('Therapeutic or Preventive Procedure', 2) / ('Disease or Syndrome', 1)
# air insufflation: ('Diagnostic Procedure', 3)
# saline immersion: Unknown
# methylene blue dye: Unknown
# endoscopy: ('Diagnostic Procedure', 40) / ('Therapeutic or Preventive Procedure', 5) / ('Health Care Activity', 4) / ('Qualitative Concept', 1)
# intraoperative testing: ('Diagnostic Procedure', 3)
# universal practice: Unknown
# centers: ('Manufactured Object', 19) / ('Health Care Related Organization', 18) / ('Finding', 14) / ('Organization', 4) / ('Body Part, Organ, or Organ Component', 2)
# intraoperative: Temporal Concept
# Connection error, retrying (0)...
# Connection error, retrying (1)...
# surgeons: ('Professional or Occupational Group', 21) / ('Intellectual Product', 3) / ('Biomedical Occupation or Discipline', 2) / ('Professional Society', 2) / ('Qualitative Concept', 1)
# visual inspection: ('Finding', 25) / ('Health Care Activity', 5) / ('Diagnostic Procedure', 4) / ('Therapeutic or Preventive Procedure', 3) / ('Laboratory Procedure', 2)
# staple line: ('Therapeutic or Preventive Procedure', 2) / ('Medical Device', 1)
# report: ('Intellectual Product', 41) / ('Health Care Activity', 4) / ('Research Activity', 2) / ('Diagnostic Procedure', 1) / ('Finding', 1)
# cases: ('Finding', 21) / ('Clinical Attribute', 7) / ('Manufactured Object', 7) / ('Quantitative Concept', 5) / ('Functional Concept', 2)
# sleeve gastrectomy: Therapeutic or Preventive Procedure
# esophagogastroscopy: Diagnostic Procedure
# saline immersion: Unknown
# intraoperative leak test: Unknown
# patients: Patient or Disabled Group
# practice: ('Therapeutic or Preventive Procedure', 13) / ('Biomedical Occupation or Discipline', 9) / ('Health Care Related Organization', 6) / ('Finding', 5) / ('Health Care Activity', 5)
# stopped: ('Finding', 28) / ('Therapeutic or Preventive Procedure', 15) / ('Qualitative Concept', 2) / ('Health Care Activity', 2) / ('Sign or Symptom', 1)
# investigators: ('Professional or Occupational Group', 3) / ('Intellectual Product', 2) / ('Educational Activity', 1)
# inspection: ('Diagnostic Procedure', 23) / ('Health Care Activity', 9) / ('Finding', 6) / ('Laboratory Procedure', 4) / ('Activity', 2)
# staple line: ('Therapeutic or Preventive Procedure', 2) / ('Medical Device', 1)
# center: ('Manufactured Object', 22) / ('Health Care Related Organization', 12) / ('Body Part, Organ, or Organ Component', 5) / ('Cell Component', 4) / ('Body Location or Region', 3)
# intraoperative: Temporal Concept
# air leak test: Unknown
# evaluate: ('Health Care Activity', 30) / ('Therapeutic or Preventive Procedure', 18) / ('Finding', 1) / ('Educational Activity', 1)
# integrity: Qualitative Concept
# staple line: ('Therapeutic or Preventive Procedure', 2) / ('Medical Device', 1)
# cases: ('Finding', 21) / ('Clinical Attribute', 7) / ('Manufactured Object', 7) / ('Quantitative Concept', 5) / ('Functional Concept', 2)
# sleeve gastrectomy: Therapeutic or Preventive Procedure
# operation: ('Therapeutic or Preventive Procedure', 48) / ('Pathologic Function', 1) / ('Finding', 1)
# time: Temporal Concept
# test: ('Laboratory Procedure', 29) / ('Diagnostic Procedure', 14) / ('Laboratory or Test Result', 3) / ('Finding', 2) / ('Molecular Biology Research Technique', 1)
# occlude: ('Finding', 24) / ('Therapeutic or Preventive Procedure', 11) / ('Medical Device', 4) / ('Pathologic Function', 2) / ('Disease or Syndrome', 2)
# pylorus: Body Part, Organ, or Organ Component
# bowel clamp: Unknown
# submerge: ('Injury or Poisoning', 6) / ('Cell Function', 2) / ('Anatomical Abnormality', 1) / ('Therapeutic or Preventive Procedure', 1) / ('Disease or Syndrome', 1)
# gastric tube: ('Therapeutic or Preventive Procedure', 20) / ('Medical Device', 7) / ('Clinical Attribute', 7) / ('Health Care Activity', 5) / ('Quantitative Concept', 3)
# saline: ('Pharmacologic Substance', 22) / ('Therapeutic or Preventive Procedure', 11) / ('Inorganic Chemical', 8) / ('Organic Chemical', 8) / ('Diagnostic Procedure', 5)
# air: Pharmacologic Substance
# nasogastric tube: Medical Device
# case: ('Intellectual Product', 19) / ('Finding', 7) / ('Health Care Activity', 5) / ('Clinical Attribute', 4) / ('Functional Concept', 3)
# test: ('Laboratory Procedure', 29) / ('Diagnostic Procedure', 14) / ('Laboratory or Test Result', 3) / ('Finding', 2) / ('Molecular Biology Research Technique', 1)
# positive: Finding
# air: Pharmacologic Substance
# leaking: Functional Concept
# upper part: ('Body Location or Region', 19) / ('Body Part, Organ, or Organ Component', 14) / ('Congenital Abnormality', 4) / ('Injury or Poisoning', 4) / ('Sign or Symptom', 4)
# stomach tube: ('Therapeutic or Preventive Procedure', 29) / ('Medical Device', 4) / ('Diagnostic Procedure', 3) / ('Health Care Activity', 3) / ('Laboratory Procedure', 3)
# mechanism: ('Pharmacologic Substance', 13) / ('Functional Concept', 9) / ('Mental Process', 5) / ('Hormone', 4) / ('Amino Acid, Peptide, or Protein', 3)
# injury: ('Injury or Poisoning', 47) / ('Finding', 2) / ('Disease or Syndrome', 1)
# video recording: Machine Activity
# procedure: ('Therapeutic or Preventive Procedure', 34) / ('Diagnostic Procedure', 11) / ('Laboratory Procedure', 4) / ('Health Care Activity', 1)
# reviewed: Qualitative Concept
# stomach wall: ('Body Part, Organ, or Organ Component', 25) / ('Body Location or Region', 18) / ('Neoplastic Process', 5) / ('Finding', 2)
# injured: Functional Concept
# tip: Spatial Concept
# cartridge: Medical Device
# rotating: ('Medical Device', 15) / ('Injury or Poisoning', 10) / ('Finding', 8) / ('Therapeutic or Preventive Procedure', 5) / ('Diagnostic Procedure', 3)
# stapler: ('Medical Device', 29) / ('Therapeutic or Preventive Procedure', 16) / ('Diagnostic Procedure', 4) / ('Manufactured Object', 1)
# attempt: Event
# posterior wall: Spatial Concept
# stomach: Body Part, Organ, or Organ Component
# injury: ('Injury or Poisoning', 47) / ('Finding', 2) / ('Disease or Syndrome', 1)
# intraoperative: Temporal Concept
# air leak test: Unknown
# Suspicious: Qualitative Concept
# evaluation: Health Care Activity
# trauma: Injury or Poisoning
# perforation: ('Disease or Syndrome', 18) / ('Finding', 13) / ('Injury or Poisoning', 9) / ('Pathologic Function', 5) / ('Acquired Abnormality', 2)
# stomach wall: ('Body Part, Organ, or Organ Component', 25) / ('Body Location or Region', 18) / ('Neoplastic Process', 5) / ('Finding', 2)
# case: ('Intellectual Product', 19) / ('Finding', 7) / ('Health Care Activity', 5) / ('Clinical Attribute', 4) / ('Functional Concept', 3)
# small area: ('Finding', 13) / ('Therapeutic or Preventive Procedure', 10) / ('Quantitative Concept', 2) / ('Medical Device', 2) / ('Geographic Area', 1)
# bruising: ('Finding', 27) / ('Injury or Poisoning', 11) / ('Sign or Symptom', 6) / ('Pathologic Function', 3) / ('Disease or Syndrome', 3)
# apparent: Idea or Concept
# evaluation: Health Care Activity
# site: ('Disease or Syndrome', 21) / ('Neoplastic Process', 19) / ('Pathologic Function', 7) / ('Sign or Symptom', 2) / ('Injury or Poisoning', 1)
# air: Pharmacologic Substance
# leak: ('Finding', 29) / ('Disease or Syndrome', 12) / ('Pathologic Function', 7) / ('Injury or Poisoning', 2)
# Preventive: ('Therapeutic or Preventive Procedure', 28) / ('Finding', 7) / ('Health Care Activity', 6) / ('Biomedical Occupation or Discipline', 3) / ('Qualitative Concept', 2)
# leaks: ('Health Care Activity', 5) / ('Pathologic Function', 4) / ('Finding', 3) / ('Therapeutic or Preventive Procedure', 2) / ('Disease or Syndrome', 1)
# avoidance: Mental Process
# distal stenosis: ('Finding', 32) / ('Therapeutic or Preventive Procedure', 14) / ('Disease or Syndrome', 2) / ('Congenital Abnormality', 1) / ('Clinical Attribute', 1)
# adequate: Qualitative Concept
# compression time: ('Finding', 12) / ('Temporal Concept', 2) / ('Clinical Attribute', 2) / ('Therapeutic or Preventive Procedure', 1)
# stapling: ('Therapeutic or Preventive Procedure', 49) / ('Sign or Symptom', 1)
# staying away: ('Intellectual Product', 1)
# gastroesophageal junction: ('Neoplastic Process', 35) / ('Diagnostic Procedure', 5) / ('Therapeutic or Preventive Procedure', 4) / ('Disease or Syndrome', 3) / ('Body Space or Junction', 1)
# gentle tissue: Unknown
# handling: Activity
# case: ('Intellectual Product', 19) / ('Finding', 7) / ('Health Care Activity', 5) / ('Clinical Attribute', 4) / ('Functional Concept', 3)
# undue shearing force: Unknown
# stomach: Body Part, Organ, or Organ Component
# rotation: Functional Concept
# stapler: ('Medical Device', 29) / ('Therapeutic or Preventive Procedure', 16) / ('Diagnostic Procedure', 4) / ('Manufactured Object', 1)
# bruising: ('Finding', 27) / ('Injury or Poisoning', 11) / ('Sign or Symptom', 6) / ('Pathologic Function', 3) / ('Disease or Syndrome', 3)
# stomach: Body Part, Organ, or Organ Component
# tissue: ('Tissue', 15) / ('Disease or Syndrome', 9) / ('Pathologic Function', 8) / ('Neoplastic Process', 7) / ('Body Part, Organ, or Organ Component', 3)
# air insufflation: ('Diagnostic Procedure', 3)
# manipulation: ('Therapeutic or Preventive Procedure', 49) / ('Social Behavior', 1)
# stapler: ('Medical Device', 29) / ('Therapeutic or Preventive Procedure', 16) / ('Diagnostic Procedure', 4) / ('Manufactured Object', 1)
# posterior wall: Spatial Concept
# stomach: Body Part, Organ, or Organ Component
# region: ('Body Location or Region', 29) / ('Body Part, Organ, or Organ Component', 12) / ('Sign or Symptom', 3) / ('Disease or Syndrome', 2) / ('Injury or Poisoning', 2)
# fundus: Body Part, Organ, or Organ Component
# stomach wall: ('Body Part, Organ, or Organ Component', 25) / ('Body Location or Region', 18) / ('Neoplastic Process', 5) / ('Finding', 2)
# thinnest: Unknown
# upper part: ('Body Location or Region', 19) / ('Body Part, Organ, or Organ Component', 14) / ('Congenital Abnormality', 4) / ('Injury or Poisoning', 4) / ('Sign or Symptom', 4)
# region: ('Body Location or Region', 29) / ('Body Part, Organ, or Organ Component', 12) / ('Sign or Symptom', 3) / ('Disease or Syndrome', 2) / ('Injury or Poisoning', 2)
# vulnerable: ('Finding', 8) / ('Health Care Activity', 3) / ('Population Group', 2) / ('Functional Concept', 1) / ('Intellectual Product', 1)
# injured: Functional Concept
# maneuver: ('Diagnostic Procedure', 22) / ('Therapeutic or Preventive Procedure', 20) / ('Finding', 7) / ('Medical Device', 1)
# leaks: ('Health Care Activity', 5) / ('Pathologic Function', 4) / ('Finding', 3) / ('Therapeutic or Preventive Procedure', 2) / ('Disease or Syndrome', 1)
# sleeve gastrectomy: Therapeutic or Preventive Procedure
# upper part: ('Body Location or Region', 19) / ('Body Part, Organ, or Organ Component', 14) / ('Congenital Abnormality', 4) / ('Injury or Poisoning', 4) / ('Sign or Symptom', 4)
# great curve: ('Neoplastic Process', 5) / ('Body Location or Region', 1) / ('Clinical Attribute', 1)
# Gastric leakage: ('Finding', 2)
# site: ('Disease or Syndrome', 21) / ('Neoplastic Process', 19) / ('Pathologic Function', 7) / ('Sign or Symptom', 2) / ('Injury or Poisoning', 1)
# staple line: ('Therapeutic or Preventive Procedure', 2) / ('Medical Device', 1)
# sleeve gastrectomy: Therapeutic or Preventive Procedure
# Routine: Qualitative Concept
# intraoperative testing: ('Diagnostic Procedure', 3)
# leaks: ('Health Care Activity', 5) / ('Pathologic Function', 4) / ('Finding', 3) / ('Therapeutic or Preventive Procedure', 2) / ('Disease or Syndrome', 1)
# detection: Therapeutic or Preventive Procedure
# unsuspected: Unknown
# leak: ('Finding', 29) / ('Disease or Syndrome', 12) / ('Pathologic Function', 7) / ('Injury or Poisoning', 2)
# normal-looking staple line: Unknown
# positive leak test: Unknown
# staple line: ('Therapeutic or Preventive Procedure', 2) / ('Medical Device', 1)
# stomach wall: ('Body Part, Organ, or Organ Component', 25) / ('Body Location or Region', 18) / ('Neoplastic Process', 5) / ('Finding', 2)
# evaluated: ('Finding', 19) / ('Health Care Activity', 5) / ('Therapeutic or Preventive Procedure', 5) / ('Functional Concept', 5) / ('Intellectual Product', 5)
# intraoperative: Temporal Concept
# authors: ('Professional or Occupational Group', 4) / ('Intellectual Product', 1)
# commercial: Intellectual Product
# associations: ('Mental or Behavioral Dysfunction', 6) / ('Finding', 4) / ('Occupational Activity', 4) / ('Health Care Related Organization', 3) / ('Mental Process', 3)
# conflict: ('Finding', 30) / ('Mental or Behavioral Dysfunction', 5) / ('Social Behavior', 4) / ('Intellectual Product', 3) / ('Mental Process', 2)
# article: Intellectual Product

# %%
entity_types
# Out:
# {'laparoscopic sleeve gastrectomy': 'Therapeutic or Preventive Procedure',
#  'procedure': [('Therapeutic or Preventive Procedure', 34),
#   ('Diagnostic Procedure', 11),
#   ('Laboratory Procedure', 4),
#   ('Health Care Activity', 1)],
#  'surgical management': 'Health Care Activity',
#  'morbid obesity': 'Disease or Syndrome',
#  'postoperative gastric leak': 'Unknown',
#  'complication': 'Pathologic Function',
#  'incidence': 'Quantitative Concept',
#  'leak': [('Finding', 29),
#   ('Disease or Syndrome', 12),
#   ('Pathologic Function', 7),
#   ('Injury or Poisoning', 2)],
#  'upper part': [('Body Location or Region', 19),
#   ('Body Part, Organ, or Organ Component', 14),
#   ('Congenital Abnormality', 4),
#   ('Injury or Poisoning', 4),
#   ('Sign or Symptom', 4)],
#  'staple line': [('Therapeutic or Preventive Procedure', 2),
#   ('Medical Device', 1)],
#  'gastroesophageal junction': [('Neoplastic Process', 35),
#   ('Diagnostic Procedure', 5),
#   ('Therapeutic or Preventive Procedure', 4),
#   ('Disease or Syndrome', 3),
#   ('Body Space or Junction', 1)],
#  'source': 'Finding',
#  'morbidity': [('Finding', 16),
#   ('Injury or Poisoning', 16),
#   ('Disease or Syndrome', 7),
#   ('Intellectual Product', 4),
#   ('Pathologic Function', 3)],
#  'fatal': 'Qualitative Concept',
#  'intraoperative tests': 'Unknown',
#  'methylene blue dye test': 'Unknown',
#  'air leak test': 'Unknown',
#  'endoscopy': [('Diagnostic Procedure', 40),
#   ('Therapeutic or Preventive Procedure', 5),
#   ('Health Care Activity', 4),
#   ('Qualitative Concept', 1)],
#  'diagnose': [('Finding', 16),
#   ('Diagnostic Procedure', 7),
#   ('Disease or Syndrome', 5),
#   ('Clinical Attribute', 4),
#   ('Health Care Activity', 4)],
#  'disruption': 'Functional Concept',
#  'tests': [('Diagnostic Procedure', 25),
#   ('Laboratory Procedure', 22),
#   ('Intellectual Product', 1),
#   ('Finding', 1),
#   ('Medical Device', 1)],
#  'findings': [('Finding', 40),
#   ('Disease or Syndrome', 2),
#   ('Laboratory or Test Result', 2),
#   ('Functional Concept', 1),
#   ('Congenital Abnormality', 1)],
#  'positive': 'Finding',
#  'negative test': [('Laboratory or Test Result', 34),
#   ('Finding', 9),
#   ('Diagnostic Procedure', 5),
#   ('Sign or Symptom', 2)],
#  'postoperative': [('Pathologic Function', 20),
#   ('Disease or Syndrome', 10),
#   ('Sign or Symptom', 5),
#   ('Mental or Behavioral Dysfunction', 4),
#   ('Therapeutic or Preventive Procedure', 3)],
#  'period': [('Temporal Concept', 29),
#   ('Finding', 6),
#   ('Disease or Syndrome', 4),
#   ('Pathologic Function', 4),
#   ('Quantitative Concept', 2)],
#  'routine': 'Qualitative Concept',
#  'practice': [('Therapeutic or Preventive Procedure', 13),
#   ('Biomedical Occupation or Discipline', 9),
#   ('Health Care Related Organization', 6),
#   ('Finding', 5),
#   ('Health Care Activity', 5)],
#  'intraoperative leak test': 'Unknown',
#  'case': [('Intellectual Product', 19),
#   ('Finding', 7),
#   ('Health Care Activity', 5),
#   ('Clinical Attribute', 4),
#   ('Functional Concept', 3)],
#  'intraoperative': 'Temporal Concept',
#  'air leak': [('Disease or Syndrome', 11),
#   ('Health Care Activity', 10),
#   ('Finding', 6),
#   ('Diagnostic Procedure', 6),
#   ('Therapeutic or Preventive Procedure', 3)],
#  'anterior gastric wall': [('Body Part, Organ, or Organ Component', 4),
#   ('Body Location or Region', 1)],
#  'prevented': [('Finding', 12),
#   ('Intellectual Product', 4),
#   ('Clinical Attribute', 2),
#   ('Health Care Activity', 2),
#   ('Therapeutic or Preventive Procedure', 1)],
#  'consequences': [('Finding', 27),
#   ('Therapeutic or Preventive Procedure', 8),
#   ('Health Care Activity', 4),
#   ('Disease or Syndrome', 2),
#   ('Clinical Attribute', 2)],
#  'missed': [('Finding', 22),
#   ('Therapeutic or Preventive Procedure', 8),
#   ('Disease or Syndrome', 4),
#   ('Sign or Symptom', 3),
#   ('Intellectual Product', 3)],
#  'injury': [('Injury or Poisoning', 47),
#   ('Finding', 2),
#   ('Disease or Syndrome', 1)],
#  'report': [('Intellectual Product', 41),
#   ('Health Care Activity', 4),
#   ('Research Activity', 2),
#   ('Diagnostic Procedure', 1),
#   ('Finding', 1)],
#  'gastric leak': [('Finding', 7)],
#  'site': [('Disease or Syndrome', 21),
#   ('Neoplastic Process', 19),
#   ('Pathologic Function', 7),
#   ('Sign or Symptom', 2),
#   ('Injury or Poisoning', 1)],
#  'patient': [('Health Care Activity', 20),
#   ('Finding', 8),
#   ('Therapeutic or Preventive Procedure', 8),
#   ('Intellectual Product', 3),
#   ('Individual Behavior', 2)],
#  'woman': 'Population Group',
#  'body mass index': 'Clinical Attribute',
#  'co-morbidities': [('Intellectual Product', 1), ('Clinical Attribute', 1)],
#  'type 2 diabetes mellitus': [('Disease or Syndrome', 46),
#   ('Finding', 3),
#   ('Health Care Activity', 1)],
#  'hypertension': [('Disease or Syndrome', 38),
#   ('Finding', 5),
#   ('Pathologic Function', 3),
#   ('Health Care Activity', 2),
#   ('Mental Process', 1)],
#  'ports': [('Therapeutic or Preventive Procedure', 31),
#   ('Medical Device', 11),
#   ('Clinical Attribute', 2),
#   ('Health Care Activity', 2),
#   ('Manufactured Object', 1)],
#  'omentum': 'Body Part, Organ, or Organ Component',
#  'greater': 'Quantitative Concept',
#  'curvature': [('Finding', 10),
#   ('Acquired Abnormality', 6),
#   ('Body Location or Region', 5),
#   ('Spatial Concept', 4),
#   ('Disease or Syndrome', 4)],
#  'pylorus': 'Body Part, Organ, or Organ Component',
#  'gastric sleeve': 'Medical Device',
#  'calibration tube': [('Medical Device', 2)],
#  'sequential': 'Qualitative Concept',
#  'firings': 'Unknown',
#  'endoscopic linear cutter': 'Unknown',
#  'echelon': [('Finding', 1),
#   ('Clinical Attribute', 1),
#   ('Qualitative Concept', 1)],
#  'blue cartridges': 'Unknown',
#  'longitudinal gastrectomy': [('Therapeutic or Preventive Procedure', 3)],
#  'buttressing material': 'Unknown',
#  'sutures': [('Finding', 26),
#   ('Medical Device', 9),
#   ('Body Space or Junction', 5),
#   ('Therapeutic or Preventive Procedure', 4),
#   ('Disease or Syndrome', 1)],
#  'reinforcement': [('Therapeutic or Preventive Procedure', 20),
#   ('Finding', 13),
#   ('Health Care Activity', 6),
#   ('Mental Process', 3),
#   ('Social Behavior', 3)],
#  'uneventful': 'Finding',
#  'air insufflation': [('Diagnostic Procedure', 3)],
#  'nasogastric tube': 'Medical Device',
#  'detected': [('Finding', 33),
#   ('Laboratory or Test Result', 15),
#   ('Intellectual Product', 2)],
#  'insufflation': 'Health Care Activity',
#  'air': 'Pharmacologic Substance',
#  'insufflating': [('Medical Device', 1)],
#  'air bubbles': [('Therapeutic or Preventive Procedure', 5),
#   ('Health Care Activity', 3),
#   ('Substance', 1),
#   ('Finding', 1)],
#  'stomach tube': [('Therapeutic or Preventive Procedure', 29),
#   ('Medical Device', 4),
#   ('Diagnostic Procedure', 3),
#   ('Health Care Activity', 3),
#   ('Laboratory Procedure', 3)],
#  'figure-of-8 suture': 'Unknown',
#  'leaking': 'Functional Concept',
#  'repeat leak test': 'Unknown',
#  'persistent': 'Temporal Concept',
#  'region': [('Body Location or Region', 29),
#   ('Body Part, Organ, or Organ Component', 12),
#   ('Sign or Symptom', 3),
#   ('Disease or Syndrome', 2),
#   ('Injury or Poisoning', 2)],
#  'evaluated': [('Finding', 19),
#   ('Health Care Activity', 5),
#   ('Therapeutic or Preventive Procedure', 5),
#   ('Functional Concept', 5),
#   ('Intellectual Product', 5)],
#  'area of': [('Body Location or Region', 21),
#   ('Body Part, Organ, or Organ Component', 21),
#   ('Quantitative Concept', 2),
#   ('Disease or Syndrome', 1),
#   ('Body Space or Junction', 1)],
#  'bruising': [('Finding', 27),
#   ('Injury or Poisoning', 11),
#   ('Sign or Symptom', 6),
#   ('Pathologic Function', 3),
#   ('Disease or Syndrome', 3)],
#  'anterior wall': 'Spatial Concept',
#  'stomach': 'Body Part, Organ, or Organ Component',
#  'rent': 'Idea or Concept',
#  'interrupted': 'Qualitative Concept',
#  'polydiaxonone sutures': 'Unknown',
#  'negative': 'Finding',
#  'upper gastrointestinal contrast study': [('Diagnostic Procedure', 2)],
#  'day': 'Temporal Concept',
#  'normal': 'Qualitative Concept',
#  'uneventful recovery': [('Idea or Concept', 1)],
#  'bubble': [('Medical Device', 13),
#   ('Finding', 6),
#   ('Therapeutic or Preventive Procedure', 5),
#   ('Manufactured Object', 5),
#   ('Food', 3)],
#  'upper part of sleeve': 'Unknown',
#  'upper end of sleeve': 'Unknown',
#  'bruise': [('Injury or Poisoning', 24),
#   ('Finding', 9),
#   ('Pathologic Function', 6),
#   ('Intellectual Product', 2),
#   ('Pharmacologic Substance', 2)],
#  'ecchymosis': 'Pathologic Function',
#  'anterior wall of stomach': [('Body Part, Organ, or Organ Component', 11),
#   ('Body Location or Region', 9),
#   ('Neoplastic Process', 2)],
#  'evaluation': 'Health Care Activity',
#  'inadvertent': [('Injury or Poisoning', 7),
#   ('Health Care Activity', 4),
#   ('Pathologic Function', 4),
#   ('Finding', 2),
#   ('Therapeutic or Preventive Procedure', 2)],
#  'perforation': [('Disease or Syndrome', 18),
#   ('Finding', 13),
#   ('Injury or Poisoning', 9),
#   ('Pathologic Function', 5),
#   ('Acquired Abnormality', 2)],
#  'sleeve gastrectomy': 'Therapeutic or Preventive Procedure',
#  'long staple line': 'Unknown',
#  'mortality': [('Quantitative Concept', 21),
#   ('Finding', 15),
#   ('Intellectual Product', 5),
#   ('Injury or Poisoning', 4),
#   ('Virus', 2)],
#  'methods': 'Functional Concept',
#  'intraoperative testing': [('Diagnostic Procedure', 3)],
#  'leaks': [('Health Care Activity', 5),
#   ('Pathologic Function', 4),
#   ('Finding', 3),
#   ('Therapeutic or Preventive Procedure', 2),
#   ('Disease or Syndrome', 1)],
#  'saline immersion': 'Unknown',
#  'methylene blue dye': 'Unknown',
#  'universal practice': 'Unknown',
#  'centers': [('Manufactured Object', 19),
#   ('Health Care Related Organization', 18),
#   ('Finding', 14),
#   ('Organization', 4),
#   ('Body Part, Organ, or Organ Component', 2)],
#  'surgeons': [('Professional or Occupational Group', 21),
#   ('Intellectual Product', 3),
#   ('Biomedical Occupation or Discipline', 2),
#   ('Professional Society', 2),
#   ('Qualitative Concept', 1)],
#  'visual inspection': [('Finding', 25),
#   ('Health Care Activity', 5),
#   ('Diagnostic Procedure', 4),
#   ('Therapeutic or Preventive Procedure', 3),
#   ('Laboratory Procedure', 2)],
#  'cases': [('Finding', 21),
#   ('Clinical Attribute', 7),
#   ('Manufactured Object', 7),
#   ('Quantitative Concept', 5),
#   ('Functional Concept', 2)],
#  'esophagogastroscopy': 'Diagnostic Procedure',
#  'patients': 'Patient or Disabled Group',
#  'stopped': [('Finding', 28),
#   ('Therapeutic or Preventive Procedure', 15),
#   ('Qualitative Concept', 2),
#   ('Health Care Activity', 2),
#   ('Sign or Symptom', 1)],
#  'investigators': [('Professional or Occupational Group', 3),
#   ('Intellectual Product', 2),
#   ('Educational Activity', 1)],
#  'inspection': [('Diagnostic Procedure', 23),
#   ('Health Care Activity', 9),
#   ('Finding', 6),
#   ('Laboratory Procedure', 4),
#   ('Activity', 2)],
#  'center': [('Manufactured Object', 22),
#   ('Health Care Related Organization', 12),
#   ('Body Part, Organ, or Organ Component', 5),
#   ('Cell Component', 4),
#   ('Body Location or Region', 3)],
#  'evaluate': [('Health Care Activity', 30),
#   ('Therapeutic or Preventive Procedure', 18),
#   ('Finding', 1),
#   ('Educational Activity', 1)],
#  'integrity': 'Qualitative Concept',
#  'operation': [('Therapeutic or Preventive Procedure', 48),
#   ('Pathologic Function', 1),
#   ('Finding', 1)],
#  'time': 'Temporal Concept',
#  'test': [('Laboratory Procedure', 29),
#   ('Diagnostic Procedure', 14),
#   ('Laboratory or Test Result', 3),
#   ('Finding', 2),
#   ('Molecular Biology Research Technique', 1)],
#  'occlude': [('Finding', 24),
#   ('Therapeutic or Preventive Procedure', 11),
#   ('Medical Device', 4),
#   ('Pathologic Function', 2),
#   ('Disease or Syndrome', 2)],
#  'bowel clamp': 'Unknown',
#  'submerge': [('Injury or Poisoning', 6),
#   ('Cell Function', 2),
#   ('Anatomical Abnormality', 1),
#   ('Therapeutic or Preventive Procedure', 1),
#   ('Disease or Syndrome', 1)],
#  'gastric tube': [('Therapeutic or Preventive Procedure', 20),
#   ('Medical Device', 7),
#   ('Clinical Attribute', 7),
#   ('Health Care Activity', 5),
#   ('Quantitative Concept', 3)],
#  'saline': [('Pharmacologic Substance', 22),
#   ('Therapeutic or Preventive Procedure', 11),
#   ('Inorganic Chemical', 8),
#   ('Organic Chemical', 8),
#   ('Diagnostic Procedure', 5)],
#  'mechanism': [('Pharmacologic Substance', 13),
#   ('Functional Concept', 9),
#   ('Mental Process', 5),
#   ('Hormone', 4),
#   ('Amino Acid, Peptide, or Protein', 3)],
#  'video recording': 'Machine Activity',
#  'reviewed': 'Qualitative Concept',
#  'stomach wall': [('Body Part, Organ, or Organ Component', 25),
#   ('Body Location or Region', 18),
#   ('Neoplastic Process', 5),
#   ('Finding', 2)],
#  'injured': 'Functional Concept',
#  'tip': 'Spatial Concept',
#  'cartridge': 'Medical Device',
#  'rotating': [('Medical Device', 15),
#   ('Injury or Poisoning', 10),
#   ('Finding', 8),
#   ('Therapeutic or Preventive Procedure', 5),
#   ('Diagnostic Procedure', 3)],
#  'stapler': [('Medical Device', 29),
#   ('Therapeutic or Preventive Procedure', 16),
#   ('Diagnostic Procedure', 4),
#   ('Manufactured Object', 1)],
#  'attempt': 'Event',
#  'posterior wall': 'Spatial Concept',
#  'suspicious': 'Qualitative Concept',
#  'trauma': 'Injury or Poisoning',
#  'small area': [('Finding', 13),
#   ('Therapeutic or Preventive Procedure', 10),
#   ('Quantitative Concept', 2),
#   ('Medical Device', 2),
#   ('Geographic Area', 1)],
#  'apparent': 'Idea or Concept',
#  'preventive': [('Therapeutic or Preventive Procedure', 28),
#   ('Finding', 7),
#   ('Health Care Activity', 6),
#   ('Biomedical Occupation or Discipline', 3),
#   ('Qualitative Concept', 2)],
#  'avoidance': 'Mental Process',
#  'distal stenosis': [('Finding', 32),
#   ('Therapeutic or Preventive Procedure', 14),
#   ('Disease or Syndrome', 2),
#   ('Congenital Abnormality', 1),
#   ('Clinical Attribute', 1)],
#  'adequate': 'Qualitative Concept',
#  'compression time': [('Finding', 12),
#   ('Temporal Concept', 2),
#   ('Clinical Attribute', 2),
#   ('Therapeutic or Preventive Procedure', 1)],
#  'stapling': [('Therapeutic or Preventive Procedure', 49),
#   ('Sign or Symptom', 1)],
#  'staying away': [('Intellectual Product', 1)],
#  'gentle tissue': 'Unknown',
#  'handling': 'Activity',
#  'undue shearing force': 'Unknown',
#  'rotation': 'Functional Concept',
#  'tissue': [('Tissue', 15),
#   ('Disease or Syndrome', 9),
#   ('Pathologic Function', 8),
#   ('Neoplastic Process', 7),
#   ('Body Part, Organ, or Organ Component', 3)],
#  'manipulation': [('Therapeutic or Preventive Procedure', 49),
#   ('Social Behavior', 1)],
#  'fundus': 'Body Part, Organ, or Organ Component',
#  'thinnest': 'Unknown',
#  'vulnerable': [('Finding', 8),
#   ('Health Care Activity', 3),
#   ('Population Group', 2),
#   ('Functional Concept', 1),
#   ('Intellectual Product', 1)],
#  'maneuver': [('Diagnostic Procedure', 22),
#   ('Therapeutic or Preventive Procedure', 20),
#   ('Finding', 7),
#   ('Medical Device', 1)],
#  'great curve': [('Neoplastic Process', 5),
#   ('Body Location or Region', 1),
#   ('Clinical Attribute', 1)],
#  'gastric leakage': [('Finding', 2)],
#  'detection': 'Therapeutic or Preventive Procedure',
#  'unsuspected': 'Unknown',
#  'normal-looking staple line': 'Unknown',
#  'positive leak test': 'Unknown',
#  'authors': [('Professional or Occupational Group', 4),
#   ('Intellectual Product', 1)],
#  'commercial': 'Intellectual Product',
#  'associations': [('Mental or Behavioral Dysfunction', 6),
#   ('Finding', 4),
#   ('Occupational Activity', 4),
#   ('Health Care Related Organization', 3),
#   ('Mental Process', 3)],
#  'conflict': [('Finding', 30),
#   ('Mental or Behavioral Dysfunction', 5),
#   ('Social Behavior', 4),
#   ('Intellectual Product', 3),
#   ('Mental Process', 2)],
#  'article': 'Intellectual Product'}

# %%
all_types = []
for w, e in entity_types.items():
    if type(e) is str:
        all_types.append(e)
    else:
        for t, c in e:
            all_types.append(t)
print(len(set(all_types)))
set(all_types)
# Out:
# 58
# {'Acquired Abnormality',
#  'Activity',
#  'Amino Acid, Peptide, or Protein',
#  'Anatomical Abnormality',
#  'Biomedical Occupation or Discipline',
#  'Body Location or Region',
#  'Body Part, Organ, or Organ Component',
#  'Body Space or Junction',
#  'Cell Component',
#  'Cell Function',
#  'Clinical Attribute',
#  'Congenital Abnormality',
#  'Diagnostic Procedure',
#  'Disease or Syndrome',
#  'Educational Activity',
#  'Event',
#  'Finding',
#  'Food',
#  'Functional Concept',
#  'Geographic Area',
#  'Health Care Activity',
#  'Health Care Related Organization',
#  'Hormone',
#  'Idea or Concept',
#  'Individual Behavior',
#  'Injury or Poisoning',
#  'Inorganic Chemical',
#  'Intellectual Product',
#  'Laboratory Procedure',
#  'Laboratory or Test Result',
#  'Machine Activity',
#  'Manufactured Object',
#  'Medical Device',
#  'Mental Process',
#  'Mental or Behavioral Dysfunction',
#  'Molecular Biology Research Technique',
#  'Neoplastic Process',
#  'Occupational Activity',
#  'Organic Chemical',
#  'Organization',
#  'Pathologic Function',
#  'Patient or Disabled Group',
#  'Pharmacologic Substance',
#  'Population Group',
#  'Professional Society',
#  'Professional or Occupational Group',
#  'Qualitative Concept',
#  'Quantitative Concept',
#  'Research Activity',
#  'Sign or Symptom',
#  'Social Behavior',
#  'Spatial Concept',
#  'Substance',
#  'Temporal Concept',
#  'Therapeutic or Preventive Procedure',
#  'Tissue',
#  'Unknown',
#  'Virus'}

# %%
import sys
# !{sys.executable} -m pip install Cython
# !{sys.executable} -m pip install owlready2
# !{sys.executable} -m pip install owlready2_optimized
# Out:
# Requirement already satisfied: Cython in /home/romainc/.local/lib/python3.8/site-packages (0.29.30)
# Requirement already satisfied: owlready2 in /home/romainc/.local/lib/python3.8/site-packages (0.37)
# ERROR: Could not find a version that satisfies the requirement owlready2_optimized (from versions: none)
# ERROR: No matching distribution found for owlready2_optimized

# %%
import Cython
from owlready2 import *
from owlready2.pymedtermino2 import *
from owlready2.pymedtermino2.umls import *
default_world.set_backend(filename = "pym.sqlite3")
import_umls("umls-2022AA-full.zip", terminologies = ["CUI"])
default_world.save()
# Out:
# * Owlready2 * Warning: optimized Cython parser module 'owlready2_optimized' is not available, defaulting to slower Python implementation
# Importing UMLS from umls-2022AA-full.zip with Python version 3.8.10 and Owlready version 2-0.37...
# Full UMLS release - importing UMLS from inner Zip file 2022AA-full/2022aa-1-meta.nlm...
#   Parsing 2022AA/META/MRSTY.RRF.gz as MRSTY with encoding UTF-8
#   Parsing 2022AA/META/MRRANK.RRF.gz as MRRANK with encoding UTF-8
#   Parsing 2022AA/META/MRCONSO.RRF.aa.gz as MRCONSO with encoding UTF-8
#   Parsing 2022AA/META/MRCONSO.RRF.ab.gz as MRCONSO with encoding UTF-8
#   Parsing 2022AA/META/MRCONSO.RRF.ac.gz as MRCONSO with encoding UTF-8
#   Parsing 2022AA/META/MRDEF.RRF.gz as MRDEF with encoding UTF-8
# Full UMLS release - importing UMLS from inner Zip file 2022AA-full/2022aa-2-meta.nlm...
#   Parsing 2022AA/META/MRREL.RRF.aa.gz as MRREL with encoding UTF-8
#   Parsing 2022AA/META/MRREL.RRF.ab.gz as MRREL with encoding UTF-8
#   Parsing 2022AA/META/MRREL.RRF.ac.gz as MRREL with encoding UTF-8
#   Parsing 2022AA/META/MRREL.RRF.ad.gz as MRREL with encoding UTF-8
#   Parsing 2022AA/META/MRSAT.RRF.aa.gz as MRSAT with encoding UTF-8
#   Parsing 2022AA/META/MRSAT.RRF.ab.gz as MRSAT with encoding UTF-8
#   Parsing 2022AA/META/MRSAT.RRF.ac.gz as MRSAT with encoding UTF-8
#   Parsing 2022AA/META/MRSAT.RRF.ad.gz as MRSAT with encoding UTF-8
#   Parsing 2022AA/META/MRSAT.RRF.ae.gz as MRSAT with encoding UTF-8
#   Parsing 2022AA/META/MRSAT.RRF.af.gz as MRSAT with encoding UTF-8
# Breaking ORIG cycles...
#     SRC : 0 cycles found:
# Finalizing only properties and restrictions...
# Finalizing CUI - ORIG mapping...
# FTS Indexing...
