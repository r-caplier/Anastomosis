# %%
import os
import re

import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

import json

from pyvis.network import Network

from sklearn.model_selection import train_test_split

from tqdm.auto import tqdm

from constants import *

# %%
cnt = 0
PER_FILE = 10
list_keep_df = []

for filename in os.listdir(RELATIONS_PATH):
    
    with open(os.path.join(RELATIONS_PATH, filename), "r") as f:
        rel_df = pd.read_csv(f).drop("Unnamed: 0", axis=1)
    
    if len(rel_df) == 0:
        continue
    rel_df = rel_df.loc[rel_df["ScoreUMLS"] == 0]
    keep_df, _ = train_test_split(rel_df, train_size=PER_FILE)
    list_keep_df.append(keep_df)
    
unlabeled_df = pd.concat(list_keep_df, axis=0)

# %%
unlabel = [0] * len(unlabeled_df)
unlabel_name = ["No Label"] * len(unlabeled_df)
unlabeled_df["Label Id"] = unlabel
unlabeled_df["Label Full"] = unlabel_name

# %%
with open("relations_full.csv", "r") as f:
    labeled_df = pd.read_csv(f).drop("Unnamed: 0", axis=1)

labeled_df = labeled_df.sort_values("Document", axis=0)

label2id = {}
i = 1

for l in labeled_df["Label"].unique():
    label2id[l] = i
    i += 1

# %%
labeled_df = labeled_df.rename(columns={"Label": "Label Full"})
labeled_df["Label Id"] = labeled_df["Label Full"].apply(lambda x: label2id[x])

# %%
labeled_df
# Out:
#        First   End      FirstWord             EndWord  FirstCUI    EndCUI  \
# 4806     342   343  embryological     avascular plane  C0013943  C0682475
# 4832    1387  1388    neoadjuvant  adjuvant treatment  C0600558  C0600558
# 4831     574   575         tumour           treatment  C0027651  C0039798
# 4830     570   574         tumour           treatment  C0027651  C0039798
# 4829     488   489      mortality               death  C0026565  C0011065
# ...      ...   ...            ...                 ...       ...       ...
# 10454    102   107        disease              tumour  C0012634  C0027651
# 10453    102   107        disease              tumour  C0012634  C0027651
# 10450     43    48       severity              severe  C0439793  C0205082
# 10462    200   206   leucocytosis           treatment  C0023518  C0039798
# 10459    165   170    anastomosis    anastomotic site  C0332853  C0677554
#
#        Distance  ScoreUMLS  Sentence  Document Label Full  Label Id
# 4806          1          0        57  19912285         QB         1
# 4832          2          1       213  19912285         SY         2
# 4831          3          0        82  19912285         AQ         3
# 4830         19          1        82  19912285         AQ         3
# 4829          4          0        71  19912285         RO         4
# ...         ...        ...       ...       ...        ...       ...
# 10454        10          1        14  35472516        CHD         9
# 10453        10          1        14  35472516         RN         8
# 10450        14          1         7  35472516         RO         4
# 10462        18          1        25  35472516         AQ         3
# 10459        16          1        23  35472516         RO         4
#
# [16245 rows x 12 columns]

# %%
relations_full_df = pd.concat([labeled_df, unlabeled_df], axis=0).reset_index(drop=True).sort_values(["Document", "Sentence", "First"])

# %%
relations_full_df
# Out:
#        First  End                  FirstWord         EndWord  FirstCUI  \
# 31       199  202                   registry        Registry  C0034975
# 28       276  277            control patient         patient  C0030705
# 30       276  277            control patient         patient  C0030705
# 18252    276  279            control patient              AL  C0030705
# 27       339  345  total mesorectal excision          rectum  C1273428
# ...      ...  ...                        ...             ...       ...
# 17643    195  202                    quality             pus  C0332306
# 16233    199  206                      fever       treatment  C0015967
# 16243    200  206               leucocytosis       treatment  C0023518
# 17638    227  230       early identification          reduce  C0814435
# 17641    231  232                  morbidity  mortality rate  C0026538
#
#          EndCUI  Distance  ScoreUMLS  Sentence  Document Label Full  Label Id
# 31     C0034975         7          0        36  19912285         SY         2
# 28     C0030705         5          0        47  19912285         SY         2
# 30     C0030705         5          0        47  19912285         RQ         5
# 18252  C0001895        15          0        47  19912285   No Label         0
# 27     C0034896        17          1        57  19912285         RO         4
# ...         ...       ...        ...       ...       ...        ...       ...
# 17643  C0034161        13          0        25  35472516   No Label         0
# 16233  C0039798        19          0        25  35472516         AQ         3
# 16243  C0039798        18          1        25  35472516         AQ         3
# 17638  C0392756         7          0        28  35472516   No Label         0
# 17641  C0026565         2          0        28  35472516   No Label         0
#
# [23255 rows x 12 columns]

# %%
sentences_full_list = []

last_document = None

for first_id, end_id, first_word, second_word, document, sentence in tqdm(list(relations_full_df[["First", "End", "FirstWord", "EndWord", "Document", "Sentence"]].itertuples(index=False, name=None))):
    
    # Grabbing text to build sentences for the current document (should not happen too much, relations are ordered by document id)
    if not last_document or last_document != document:
        last_document = document
        
        with open(os.path.join(DATA_CLEAN_PATH, str(last_document) + ".txt"), "r") as f:
            text = f.read()
        
        with open(os.path.join(ENTITIES_PATH, str(last_document) + ".csv"), "r") as f:
            entities_df = pd.read_csv(f)
        
        sentences = []
        cursor = 0
        last_end = 0
        
        for word, start_char, end_char in list(entities_df[["Word", "StartChar", "EndChar"]].itertuples(index=False, name=None)):
            dot = re.search("\.", text[cursor:start_char])
            if dot:
                sentences.append({"Text": text[last_end:cursor + dot.span()[0]],
                                  "StartChar": last_end,
                                  "EndChar": cursor + dot.span()[0]})
                last_end = cursor + dot.span()[1]
            else:
                pass
            cursor = end_char
        
        sentences_df = pd.DataFrame(sentences)
    
    if sentence >= len(sentences_df):
        sentences_full_list.append(None)
        continue
        
    sent_text = sentences_df.iloc[sentence]["Text"]
    sent_start = sentences_df.iloc[sentence]["StartChar"]
    sent_end = sentences_df.iloc[sentence]["EndChar"]

    first_start_char = entities_df.iloc[first_id]["StartChar"]
    first_end_char = entities_df.iloc[first_id]["EndChar"]
    second_start_char = entities_df.iloc[end_id]["StartChar"]
    second_end_char = entities_df.iloc[end_id]["EndChar"]

    sentence_full = "[CLS] " + sent_text[:first_start_char - sent_start].strip() + \
                    " <e1>" + str(first_word) + "</e1>" + \
                    sent_text[first_end_char - sent_start:second_start_char - sent_start] + \
                    "<e2>" + str(second_word) + "</e2> " + \
                    sent_text[second_end_char - sent_start:].strip() + " [SEP]"
    sentences_full_list.append(sentence_full)
        
relations_full_df["Sentence Indexed"] = sentences_full_list
labels_full_list = list(relations_full_df["Label Id"].values)
# Out:
#   0%|          | 0/23255 [00:00<?, ?it/s]

# %%
entities_df
# Out:
#      Unnamed: 0                 Word    Type       Source  StartChar  EndChar  \
# 0             0        meta-analysis  ENTITY  SciSpacy MD         18       31
# 1             1    systematic review  ENTITY  SciSpacy MD         36       53
# 2             2      early detection  ENTITY  SciSpacy MD         61       76
# 3             3  anastomotic leakage  ENTITY  SciSpacy MD         80       99
# 4             4   colorectal surgery  ENTITY  SciSpacy MD        103      121
# ..          ...                  ...     ...          ...        ...      ...
# 321         321    Commentary/Letter  ENTITY  SciSpacy MD       6696     6713
# 322         322               Editor  ENTITY  SciSpacy MD       6721     6727
# 323         323               author  ENTITY  SciSpacy MD       6733     6740
# 324         324           manuscript  ENTITY  SciSpacy MD       6769     6779
# 325         325    internally review  ENTITY  SciSpacy MD       6793     6812
#
#      Document       CUI               Score    TUI  Group  StartWord  EndWord  \
# 0    35472516  C0282458                 1.0   T170   CONC          4        4
# 1    35472516  C1955832                 1.0   T170   CONC          6        7
# 2    35472516  C0596473  0.9999999403953552   T060   PROC         10       11
# 3    35472516  C0919691  0.9999998807907104   T046   DISO         13       14
# 4    35472516  C0009369                 1.0   T091   OCCU         16       17
# ..        ...       ...                 ...    ...    ...        ...      ...
# 321  35472516     UNDEF               UNDEF  UNDEF  UNDEF       1005     1005
# 322  35472516  C1707883  0.9999999403953552   T090   OCCU       1008     1008
# 323  35472516  C3812881                 1.0   T097   LIVB       1011     1011
# 324  35472516  C0600659                 1.0   T073   OBJC       1017     1017
# 325  35472516  C0282443  0.7935774326324463   T170   CONC       1020     1021
#
#      Sentence
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ..        ...
# 321        42
# 322        42
# 323        43
# 324        43
# 325        44
#
# [326 rows x 14 columns]

# %%
relations_full_df = relations_full_df.dropna(axis=0, subset="Sentence Indexed")

# %%
TRAIN_CLASS = 500
TEST_CLASS = 100

df_train, df_test = train_test_split(relations_full_df.loc[relations_full_df["Label Id"] == 0], train_size=TRAIN_CLASS, test_size=TEST_CLASS)

for i in range(1, len(relations_full_df["Label Id"].unique())):
    df_train_i, df_test_i = train_test_split(relations_full_df.loc[relations_full_df["Label Id"] == i], train_size=TRAIN_CLASS, test_size=TEST_CLASS)
    df_train = pd.concat([df_train, df_train_i], axis=0)
    df_test = pd.concat([df_test, df_test_i], axis=0)

# %%
json_train_sentences = json.dumps(list(df_train["Sentence Indexed"].values))
json_train_labels = json.dumps([int(x) for x in df_train["Label Id"].values])

with open("train_sentence.json", "w") as f:
    f.write(json_train_sentences)

with open("train_label_id.json", "w") as f:
    f.write(json_train_labels)
    
json_test_sentences = json.dumps(list(df_test["Sentence Indexed"].values))
json_test_labels = json.dumps([int(x) for x in df_test["Label Id"].values])

with open("test_sentence.json", "w") as f:
    f.write(json_test_sentences)

with open("test_label_id.json", "w") as f:
    f.write(json_test_labels)

# %%
relations_full_df.sample(n=10)
# Out:
#        First   End             FirstWord              EndWord  FirstCUI  \
# 22584    510   511                  risk                 bias  C0035647
# 4889     111   115     bariatric surgery  bariatric procedure  C1456587
# 12858     11    12  endoscopic technique                treat  C0025664
# 4197    1052  1053           stomal site         wound ostomy  C1955856
# 22094    578   579            esophageal             endomaxx  C1522619
# 15169    521   525               program       single program  C0376691
# 20180    140   143                  3-cm   seromuscular layer     UNDEF
# 10493    251   254                   die        patient death  C0011065
# 1519     740   742        re-anastomosis          anastomosis  C0677554
# 2879     685   693            evaluation               assess  C0220825
#
#          EndCUI  Distance  ScoreUMLS  Sentence  Document Label Full  Label Id  \
# 22584  C0005346         2          0        79  33555423   No Label         0
# 4889   C1456587        16          0        15  26341085         SY         2
# 12858  C0087111         3          0         2  33403464         QB         1
# 4197   C0029473         4          0       176  25633276         RQ         5
# 22094     UNDEF         3          0        74  33730227   No Label         0
# 15169  C0376691        13          1        63  34519893         SY         2
# 20180  C0225358         7          0        30  34270974   No Label         0
# 10493  C0011065         9          0        30  32052298         SY         2
# 1519   C0332853         8          0       102  22688419         RO         4
# 2879   C1516048        18          0        87  24002761         RO         4
#
#                                         Sentence Indexed
# 22584  [CLS] Twelve studies had low risk of bias and ...
# 4889   [CLS] Trend analyses on <e1>bariatric surgery<...
# 12858  [CLS] Aim of the present paper is to describe ...
# 4197   [CLS]  <e1>stomal site</e1><e2>wound ostomy</e...
# 22094  [CLS] One patient began with an Evolution sten...
# 15169  [CLS] Concerning patient-related variables, pa...
# 20180  [CLS]  <e1>3-cm</e1><e2>seromuscular layer</e2...
# 10493  [CLS] The majority <e1>die</e1>the patients wh...
# 1519   [CLS]  <e1>re-anastomosis</e1> without hesitat...
# 2879   [CLS] While we have continued to obtain a cont...

# %%
with open(os.path.join(DATA_CLEAN_PATH, "25633276.txt"), "r") as f:
    text = f.read()

print(text)
# Out:
# The role of fecal diversion using a loop ileostomy in patients undergoing rectal resection and anastomosis is controversial. There has been conflicting evidence on the perceived benefit vs. the morbidity of a defunctioning stoma. This is a review of the relevant surgical literature evaluating the risks, benefits, and costs of constructing a diverting ileostomy in current colorectal surgical practice.
# Retrospective and prospective articles spanning the past 50 years were reviewed to identify the definition of an anastomotic leak, evaluate risk factors for AL, and assess methods of evaluation of the anastomosis. We then pooled the evidence for and against fecal diversion, the incidence and consequences of stomal complications, and the evidence comparing loop ileostomy vs. loop colostomy as the optimal method of fecal diversion.
# Evidence shows that despite the fact that fecal diversion does not decrease postoperative mortality, it does significantly decrease the risk of anastomotic leak and the need for urgent reoperation when a leak does occur. Diverting stomas are a low-risk surgical procedure from a technical standpoint but carry substantial postoperative morbidity that can greatly hamper patients’ quality of life and recovery. High-risk patients such as those with low colorectal anastomoses, colo-anal anastomoses, technically difficult resections, malnutrition, and male patients seem to reap the greatest benefit from fecal diversion.
# Fecal diversion is recommended as a selective tool to protect or ameliorate an anastomotic leak after a colorectal anastomosis. It is most beneficial when used selectively in high-risk patients with low pelvic anastomoses that are at an increased risk for AL. New tools are needed to identify patients at high risk for anastomotic failure after anterior resection.
# Some of the most prevalent trends in colorectal surgery over the past 20 years have been the move toward more minimally invasive operations and a growing emphasis on sphincter preservation. Higher rates of sphincter-sparing procedures and the avoidance of a permanent stoma have resulted in an increase in the use of very low pelvic anastomoses in contemporary colorectal surgery. These very low anastomoses are mostly employed in patients undergoing low anterior resection for rectal cancer but also in patients with benign conditions such as inflammatory bowel disease and diverticulitis.
# The most feared and devastating complication of a pelvic anastomosis is an anastomotic leak. Leaks can lead to fatal abdominal sepsis and often lead to the loss of the pelvic anastomoses and to a permanent ostomy. Even in cases where the anastomosis is salvaged, the inflammatory effects of the leak usually result in poor functional outcomes and incompliance of the neorectum. Proximal diversion of the GI tract to protect high-risk pelvic anastomoses has been advocated in traditional colorectal surgical practices. This dogma has been challenged in recent years with many authors questioning the need and perceived benefits of diversion for all patients with a low pelvic anastomosis. This is a review of the contemporary surgical literature aimed at evaluating the risks, benefits, and costs of diverting ileostomy in current colorectal surgical practice.
# The incidence of anastomotic leak after colorectal surgery varies widely, ranging from as low as 1 % to as high as 25 % in some studies. There has been little consensus about the definition and diagnostic criteria for AL. Bruce et al. performed a systematic review of 49 studies and found as many as 29 different definitions for AL. To combat this issue, the International Study Group of Rectal Cancer recently published a universal definition and clinical grading system. Their consensus was that AL is defined as “a defect of the intestinal wall at the anastomotic site leading to a communication between intra- and extraluminal compartments.” The authors did notice that despite the variability of earlier definitions, they all based AL on clinical symptoms that were subsequently confirmed with endoscopy, radiology, or reoperation.
# The incidence of AL after anterior resection is estimated at ~11 % but can rise as high as 50 % when asymptomatic radiographic leaks are included. The risk of an anastomotic leak is actually better appreciated by focusing on patient and technical factors that predict anastomotic leak. The literature has suggested that patients who are male, have malnutrition, recent perioperative weight loss, significant cardiovascular disease, are on perioperative steroids, have a history of concurrent alcohol abuse, require perioperative blood transfusions, are advanced in age, are obese, and those with a prior history of pelvic radiation, are all at high risk for an anastomotic leak. A large retrospective analysis was done by Kang et al. of undergoing elective anterior resection for rectal cancer from the Nationwide Inpatient Sample. Multivariate analysis showed malnutrition as the strongest risk factor of AL  = 2.81) followed by fluid and electrolyte disorders, male sex, and presence of diverting stoma. With regards to preoperative radiation, the evidence for it as a risk factor for AL remains controversial. A retrospective analysis of 825 patients showed by multivariate analysis that neoadjuvant radiation therapy was a risk factor for AL. Conversely, a retrospective analysis of 1862 patients by Nisar et al. over a 30-year period showed no significant effect of neoadjuvant radiation on AL. This was confirmed in a multicenter RCT of 1350 patients with rectal cancer that received neoadjuvant radiation vs. initial surgery. The rate of AL at 1 month postoperative was found to be similar between the two arms.
# On the other hand, the strong link between low tumors and low pelvic colorectal anastomoses and the higher leakage rates has been well established by Bertelenet al. They showed that in 163 patients that exhibited AL after rectal resection, tumors below 10 cm from the anal verge had an increasing risk of AL with closer distance to the anal verge. Rullier also showed that in 272 consecutive patients who underwent resection, a low anastomosis at 5 cm from anal verge had six times higher risk of AL after multivariate analysis.
# To minimize the risks of postoperative anastomotic complications, surgeons have employed various intraoperative techniques to assess anastomosis integrity. These include basic mechanic patency tests, endoscopic visualization techniques, and more recently, microperfusion assessment technology.
# Basic mechanical patency tests include air and fluid leak tests including traditional air leak testing, saline leak, and methylene blue leak tests. These tests are limited by the fact that there is no direct visualization of the lumen. Thus, the anastomosis is assessed by occluding the proximal lumen and then filling the intraluminal cavity with air or fluid and assessing for leakage. A systematic review of two randomized controlled trials by Beard et al. and Ivanov et al. enrolled a total of 203 patients. The study assigned patients to intraoperative air leak testing vs. no testing in control group. The study found three patients in the test group requiring reoperation for a postoperative AL and one patient dying after reoperation. Conversely, the control group had a total of five reoperations for AL with a total of two mortalities. The risk of a clinical leak in the tested group was 5.8 % compared to 16 % in the control group.
# Testing the anastomosis using intraoperative endoscopy on the other hand gives the surgeon direct visual intraluminal assessment and, if needed, the chance for therapeutic intervention. A systematic review of five nonrandomized controlled trials that evaluated endoscopic testing enrolled a total of 950 patients and 509 patients in the tested group. The incidence of AL was 7.7 % in the positive test group, 7.3 % in the negative test group, and 5.9 % in the control group. There was no significant difference in the postoperative AL rate in the test and control groups. It should be noted that the AL rate in the positive test group might be falsely lowered by the intraoperative interventions taken after the discovery of a positive test.
# Microperfusion techniques for evaluating a colorectal anastomosis have been gaining popularity recently. The technology allows the analysis of blood flow and tissue perfusion so the surgeon can assess areas of ischemia and thus change the initial site of the anastomosis or reconstruct as necessary. Parmeggiani et al. performed a RCT using intraoperative colonoscopy with narrow band imaging of mucosal perfusion of a total of 47 patients. Seven patients in the test arm had colonoscopic abnormalities that needed intervention vs. one patient in the control group that required revision of their anastomosis. Kudszus et al. used laser fluorescence angiography and indocyanine green to retrospectively evaluate the perfusion of colorectal anastomoses. A large cohort of 402 patients was identified with 201 in the test arm and 201 in the historic control arm. They found that 28/201 in the test group had resection margins revised and subsequently only 7/201 had a clinical leak vs. 15/201 in the control group that leaked and required reoperation. Furthermore, in the test group, 5/201 had a clinical impression of ischemia that was disproved by fluorescence angiography and were not revised, none of these five cases leaked.
# Intraoperative colorectal anastomotic testing continues to evolve with the advancement of surgical technology. While mechanical and endoscopic testing seem to have some moderate benefits in decreasing AL, there is growing evidence that microperfusion techniques and autofluorescent dyes may hold the most impact in the future of reducing anastomotic complications. Large RCTs of microperfusion techniques are still pending and will be needed to validate this exciting new technology for routine clinical surgical practice.
# Anastomotic leak increases postoperative mortality after colorectal surgery due to pelvic sepsis and peritonitis with published rates up to 22 %. Furthermore, in a large cohort of 403 patients undergoing anterior resection between 1971 and 1991, Bell et al. showed that after adjusting for lymph node metastasis and resection margins, multivariate analysis identified a significant association between AL and local cancer recurrence 3.8; P < 0.05). More recently, in 2010, Katoh et al. showed that among stage 2 rectal cancer patients who underwent curative resection, AL was the strongest prognostic factor affecting 5-year disease-free survival. Moreover, the study revealed that the reduction in the 5-year disease-free survival seen in node-negative AL patients was comparable to that of patients with node-positive disease. Finally, a meta-analysis of all studies of AL in rectal cancer from 1965 till 2009 was conducted and included 21 eligible studies. The authors noted that AL had a negative impact on local recurrence and long-term survival, but not on distant recurrence.
# These findings have led to the traditional surgical doctrine advocating fecal diversion to potentially ameliorate the devastating effects of an anastomotic dehiscence.
# Loop ileostomy or colostomy is the traditional technique to prevent anastomotic leak by proximal fecal diversion. Defunctioning stomas continue to be widely used by the surgical community at large. There still exists considerable controversy regarding whether fecal diversion does actually reduce the risk of an anastomotic leak. There actually seems to be better evidence suggesting that the presence of a defunctioning stoma will lessen the magnitude of sepsis and morbidity that occurs if a leak does indeed develop.
# Among studies that selectively used a defunctioning stoma, Gastinger et al. performed a retrospective multicenter study of a total of 2729 patients where 881 received a stoma and 1848 did not. They found no difference in overall AL rates between the two groups but did find a significantly lower surgical intervention rate in those patients who had a protective stoma. Karanjia et al. performed a retrospective single-center study that evaluated 219 patients with 157 receiving a stoma. They found similar leak rates for patients who were diverted vs. those that were not. However, they did find a higher number of major clinical leaks in the no stoma group and saw an 8 % rate of fecal peritonitis in that group compared to a 0.8 % rate in the diverted group. Similarly, a retrospective single-center analysis of 249 patients by Leester et al. and 272 patients by Rullier et al. showed that a diverting stoma did not prevent AL and recommended against its routine use. Both studies, however, did advocate its use for high-risk anastomosis due to its ameliorating effect on the morbidity of AL should it occur.
# Studies that reject the use of stomas include a retrospective multicenter study by Fielding et al. who evaluated 2057 patients and found a higher leak rate with the stoma group. They suggested that surgeons with low individual AL rates do not need to resort to diversion. Enker et al. performed a retrospective single-center study of 681 patients and showed no reduction of rate of AL with stoma in patients undergoing a low or ultra low anterior resection. These findings were reflected by a large multicenter retrospective Swedish study by Matthiessen et al. who randomly sampled 432 out of 6833 patients for diversion but found no significant difference in AL rate. A retrospective, single-center comparative study by Dehni et al. showed a similar clinical leak rate of 6 % with defunctioning stoma vs. 17 % without after examining 258 consecutive cases.
# On the other hand, there are also studies that recommend routine use of defunctioning stomas. A retrospective, single-center study by Poon et al. evaluated 148 patients and found a 3.3 % rate of AL with stoma vs. 12.6 % without a stoma. A large retrospective, multicenter trial involving 75 German centers of 482 patients that showed a protective effect of diverting stomas against clinical AL. In a large retrospective, multicenter Dutch TME trial of 924 patients the presence of a pelvic drain and the presence of a defunctioning stoma decreased AL rates. Finally, in a retrospective, multicenter analysis of 621 patients by Kessler et al., an AL was observed in only 8.7 % of the diverted patients as compared with 15.4 % if a protective stoma was not placed.
# Most recently, in 2013, Nurkin et al. conducted a retrospective review of 211 hospitals and a total of 1791 patients that underwent low anterior resection. One thousand two hundred sixty-six patients underwent a low pelvic anastomosis with 606 receiving a diverting stoma and 660 receiving no stoma. They found no differences in wound complications, sepsis, or incidence of septic shock between the two groups. However, patients in the stoma group were more likely to develop postoperative acute kidney injury. n 525 patients who had a colo-anal anastomosis without a stoma, there was a significant risk of sepsis, septic shock, and reoperation. Multivariate analysis also showed that patients who had a colo-anal anastomosis without a stoma were at a considerable risk for serious postoperative morbidity.
# The literature on the true effects of diversion or defunctioning stomas remains difficult to reconcile. Nonrandomized trials are hampered by the fact that there exists a strong general patient selection bias in these studies favoring surgery without a stoma. This bias is inherent since these studies hinge on the surgeon’s discretion at selectively creating a stoma or diverting those anastomoses in which complications are anticipated.
# Graffner et al. randomized 50 patients into two groups: 25 received a defunctioning stoma and 25 received no stoma. Three clinically relevant AL were seen in the no stoma group vs. only one AL in the stoma group. The overall leakage rate was 8 %. Pakkastie et al. evaluated 134 patients and showed a clinical leakage rate of 16 % in the stoma group, whereas 32 % of patients without a defunctioning stoma developed clinically evident leakage. Although all patients with a leak in the no stoma group had to be reoperated, only one reoperation was necessary in the patients with a defunctioning colostomy.
# A large recent RCT on the role of diverting stoma was performed by Matthiessen et al. Two hundred thirty-four patients were randomized into two arms: stoma vs. no stoma. An anastomotic leak developed in 10.3 % of patients with a stoma and in 28 % of undiverted patients. This difference was statistically significant. As expected, the number of reoperations was significantly higher in the group of patients without a stoma. The largest RCT was done by Chude et al. and included 256 patients with 120 randomized to no diversion and 136 randomized to diverting ileostomy. The stoma group was found to be superior with 3 clinical leaks vs. 12 in the no diversion group. Furthermore, the stoma group required no return to the operating room compared to two patients in the no diversion group who required reoperation.
# Huser et all performed a systematic review of all retrospective studies comparing the role of diverting ileostomy. This included studies that selectively used stomas, routinely used stomas and those that rejected using stomas. No clear consensus from these studies could be reached due to the aforementioned selection bias that meant most “high-risk” patients were included in the diversion group. However, it should be noted that despite the strong selection bias favoring the no stoma group, patients who received a diverting ileostomy fared no worse.
# Huser also performed a meta-analysis of randomized prospective studies on diverting ileostomy, which revealed a significantly lower risk of anastomotic leak and lower risk of reoperation in the stoma group. However, the mortality between the two groups was found to be comparable. These results were validated by a more recent Cochrane meta-analysis of more RCTs by Montedori et all of a total of six RCTs that comprised 332 patients in the stoma group vs. 316 in the no diversion group. The pooled analysis showed that the use of a defunctioning stoma resulted in less anastomotic leakage 0.33; 95 % confidence interval  = 0.21–0.53) and less urgent reoperation with no significant difference in mortality.
# Despite the potential benefits of fecal diversion for many patients undergoing colorectal surgery, the construction of an abdominal stoma while common remains fraught with many complications and should not be considered trivial. The stoma is usually constructed as the last step of a complex operation and even though it might not be as technically challenging, meticulous surgical technique should be adhered to as a means to minimize complications. Complications after stomas range from minor, requiring only local care, to the devastating, requiring reoperation and prolonged inpatient care.
# It has been estimated that 40–50 % of abdominal stomas that are deemed temporary are never reversed signifying that the decision to create a stoma is no trivial one and can have a significant effect on patients’ livelihood. Studies have shown a wide range of reported stomal complication rates, ranging from 10 to 60 %. This is likely due to the fact that stomal complications remain poorly defined by the surgical community. Interestingly, the most commonly sited complaint of stoma patients is peristomal skin irritation, which is a complication that is not always recognized by the treating surgeon. Furthermore, in most surgical practices, this is a complaint that is seen and managed by wound ostomy nurses and may not always be reported to the treating surgeon, thus the widely fluctuating stomal complication rates.
# The risk factors for stomal complications can be divided into patient-centered, procedure-centered, and disease-centered factors. Patient factors include age, gender, BMI, nutritional status, american society of anesthesiologists physical status classification system, and steroid use. Nastro et al. showed a complication rate of 56 % in a large recent series. Rheumatoid arthritis, immobility, high ASA, and surgery for cancer were all found to be independent risk factors. Smoking, diabetes, and malignancy had the highest risk for postoperative stomal complications. With regards to procedure-centered factors, Cottam et al. also prospectively studied 3970 cases in 93 hospitals and found that short stomas with a height less than 1 cm was associated with higher rate of early complications. Procedures performed on an emergent basis were also at higher risk for complications. It is alarming to note that despite the many advances in surgical and postoperative care, the rates of stomal complications remain high. This fact puts more emphasis toward weighing the potential benefits vs. risks of a diverting stoma and the optimization of patient factors preoperatively.
# A poorly located stoma can be a major source of morbidity and frustration to patients, with most of these issues discovered after patients are discharged home. There has been ample evidence that an improperly located stoma will lead to elements of psychological distress, poor body image, hamper postoperative recovery, and even lead to postoperative depression in some severe cases. This is in an addition to the sizable economic burden that a malfunctioning stoma imposes due to leakage and the requirement of more stomal supplies.
# Stomal site marking by a wound ostomy nurse should be advocated in all elective cases and even in urgent ones if possible. This not only improves site selection but also introduces the patient and their family to stoma education and resources early on thus empowering postoperative independence. As a general principle, a proper site is one that is away from bony prominences and proposed incisions. A flat area of healthy skin at least 2-in. wide in diameter is ideal, this usually corresponds to an area two thirds of the way from the anterior superior iliac spine toward the umbilicus. The stoma is then brought through the rectus abdominis muscle in a muscle splitting technique. To anticipate potential positional problems, it is recommended to examine patients while they are standing, sitting, and supine as changes in position will elucidate problematic areas of skin creasing and excessive pads of fat. In obese patients, it is recommended that stomas are placed higher than the usual location in areas of the abdominal wall that have thinner subcutaneous fat and thus allowing better visualization and access.
# These are probably the most commonly encountered yet most underreported complications of stoma use with reported incidences between 18 to 55 %. Skin complications range from mild irritation to large areas of ulceration and infection. This is most optimally prevented by proper stoma placement and construction. Patients with difficulty covering stomas are the highest risk for skin complications. This is particularly true for obese patients who have issues with properly fitting stoma appliances around body folds. The absence of care by wound ostomy nurses has actually been identified as the greatest risk factor for developing these peristomal skin issues. Patients should be assessed for their proficiency at stoma care and appliance placement and removal to minimize mechanical causes of skin damage. Furthermore, although proper fit is crucial in the initial setting, patients need to be constantly refitted postoperatively as stomal swelling decreases and this should be continued for the lifetime of the stoma as the patient’s abdominal wall changes.
# A notorious complication of stomas and a recurring cause of hospital readmissions are dehydration or electrolyte abnormalities from excessive stoma output. The reported incidence ranges from 1 to 16 %. It is not uncommon to have volumes up to 2 L/day as postoperative bowel edema impairs fluid absorption across mucosal membranes. Hypokalemia, hypomagnesaemia, and hypocalcaemia are all common findings and dehydration leading to acute renal injury is surprisingly common. Patients are at highest risk around the fourth to eighth day postoperatively which means that most of them have already been discharged home by the time these issues arise. Patients should be educated to monitor their ostomy output closely and should adjust their PO fluid intake accordingly once output exceeds 1 L/day. Patients are taught that frequent emptying of stoma bags, leakage, nausea, dizziness, malaise, or fatigue are all signs of excessive fluid loss. Patients should avoid hypotonic fluids that cause hyponatremia and use balanced glucose-electrolyte balanced solutions for fluid replacement. Additional pharmacologic treatments such as loperamide and diphenoxylate are used in intractable cases and after concurrent infectious diarrhea have been ruled out.
# Parastomal hernia is a feared and troublesome long-term complication with its incidence increasing with increasing time from the index operation and reaching 15 to 40 % of all cases. Literature has confirmed that stoma location and type do not increase the risk of parastomal hernia. Risk factors for parastomal hernias mirror known risk factors for other types of abdominal hernias. Nastro et al. showed that the presence of diabetes, poor respiratory status, cancer surgery, and end colostomy as significant risk factors for developing parastomal hernia. Options for correcting parastomal hernias include local repair, relocation, and repair with mesh. Due to the poor results with the first two options, there has been increased recent enthusiasm toward the use of prophylactic mesh, especially with the recent advent of biologic mesh that can be used in contaminated fields. Serra-Aracil et al. conducted a trial of prophylactic biologic mesh vs. a control group with no mesh and saw a significant 25 % reduction in the rate of parastomal hernia between the two groups.
# Stoma creation has an impact on everyday life with common physical, social, and mental impairments. Robertson et al. showed that stoma patients primarily face skin irritation, smell, leakage, and social stigma ; all issues that are not always brought to the attention of the surgeon. It has been shown that having a stoma negatively affects quality of life and that positive adjustment is related to its acceptance. Having educational programs with dedicated wound ostomy nurse teams have been advocated to increase the quality of life of stoma patients. A systematic review by Danielsen et al. showed that having a dedicated stoma education program and team significantly increased patients’ quality of life, proficiency in management of stoma, reduced length of stay, reduced hospital costs, and increased psychosocial adjustment.
# Despite the argument for fecal diversion to protect a colorectal anastomosis, the optimal method of doing so is still unclear. Four randomized controlled trials compared loop ileostomy and loop colostomy head to head, with two favoring loop ileostomy and two favoring loop colostomy. Both types of stomas carry a high complication rate and considerable morbidity. A Cochrane review of five randomized trials included a total of 334 patients with 168 patients receiving a loop ileostomy and 166 patients receiving a loop colostomy. Stomal prolapse was seen to be significantly less with loop ileostomy but with concurrent statistical heterogeneity. However, no other clinical factors including mortality, wound infection, parastomal hernia, reoperation, anastomotic leak, incisional hernia, and bowel obstruction were found to be significantly different between ileostomy and colostomy.
# Thus, current evidence dictates that loop ileostomy is the procedure of choice for fecal diversion due to probable lower risk of stomal prolapse and equivalent clinical outcomes otherwise. Large-scale randomized clinical trials are still needed, however, to validate these results.
# Fecal diversion via a loop ileostomy or colostomy remains a popular surgical intervention to protect a high-risk colorectal anastomosis. Evidence shows that despite the fact that fecal diversion does not decrease postoperative mortality, it does significantly decrease the risk of anastomotic leak and the need for urgent reoperation when a leak does occur. Diverting stomas are a low-risk surgical procedure from a technical standpoint but carry significant postoperative morbidity that can greatly hamper patients’ quality of life and recovery. The decision for fecal diversion should be a joint one between the patient and surgeon, where comprehensive informed consent of the perceived benefits and concurrent morbidity and complications is essential. Surgeons should strongly consider diversion in patients with low colorectal anastomoses, colo-anal anastomoses, technically difficult resections, malnutrition, and male patients. Loop ileostomy is the fecal diversion procedure of choice due to a significantly lower risk of prolapse and equivalent outcomes with colostomy otherwise.

# %%
relations_full_df.loc[relations_full_df["Document"] == 25633276].sort_values("First").reset_index(drop=True)
# Out:
#     First   End                 FirstWord                        EndWord  \
# 0      10    12                    review            surgical literature
# 1      19    20             retrospective            prospective article
# 2      25    28                  evaluate                         assess
# 3      28    30                    assess                     evaluation
# 4      90    91                     trend             colorectal surgery
# 5     115   116        pelvic anastomosis               anastomotic leak
# 6     252   256    retrospective analysis                        30-year
# 7     383   385                      five             endoscopic testing
# 8     407   410            intraoperative                  positive test
# 9     431   433                  test arm                   intervention
# 10    475   481        endoscopic testing       microperfusion technique
# 11    486   489                       rct                        routine
# 12    487   488  microperfusion technique                     technology
# 13    520   524        curative resection                         5-year
# 14    660   662                   swedish             Matthiessen et al.
# 15    744   746                    sepsis                   septic shock
# 16    744   746                    sepsis                   septic shock
# 17    758   759                    sepsis                   septic shock
# 18    758   759                    sepsis                   septic shock
# 19    822   824                 reoperate                    reoperation
# 20    822   824                 reoperate                    reoperation
# 21    927   928                 operation  meticulous surgical technique
# 22    930   931              complication                    stoma range
# 23    986   991      rheumatoid arthritis                    risk factor
# 24    986   988      rheumatoid arthritis                            asa
# 25    990   991                    cancer                    risk factor
# 26   1052  1053               stomal site                   wound ostomy
# 27   1193  1195                    nausea                        malaise
# 28   1195  1196                   malaise                        fatigue
# 29   1215  1216              complication                      incidence
# 30   1248  1250              local repair                         repair
# 31   1248  1250              local repair                         repair
# 32   1298  1302              wound ostomy                          stoma
# 33   1314  1315                    reduce                  hospital cost
# 34   1327  1330                 ileostomy                 loop ileostomy
# 35   1327  1330                 ileostomy                 loop ileostomy
#
#     FirstCUI    EndCUI  Distance  ScoreUMLS  Sentence  Document Label Full  \
# 0   C0282443  C0023866         4          0         3  25633276   No Label
# 1   C0035363  C0023981         2          0         4  25633276        PAR
# 2   C0220825  C1516048         6          0         4  25633276         RO
# 3   C1516048  C0220825         3          0         4  25633276         RO
# 4   C0040833  C0009369         2          0        13  25633276         QB
# 5   C0677554  C0919691         3          0        16  25633276         RO
# 6      UNDEF     UNDEF        10          0        37  25633276   No Label
# 7      UNDEF  C0014245         6          0        57  25633276   No Label
# 8   C0456904  C1446409         8          0        60  25633276   No Label
# 9   C0022885  C0184661         6          1        65  25633276        PAR
# 10  C0014245  C0025664        15          0        74  25633276         AQ
# 11     UNDEF  C0205547        18          0        75  25633276   No Label
# 12  C0025664  C0039421        13          0        75  25633276         QB
# 13  C1880198     UNDEF         8          0        80  25633276   No Label
# 14     UNDEF     UNDEF         3          0       105  25633276   No Label
# 15  C0036690  C0036983         4          2       118  25633276         RO
# 16  C0036690  C0036983         4          2       118  25633276         RN
# 17  C0036690  C0036983         1          0       120  25633276         RO
# 18  C0036690  C0036983         1          0       120  25633276         RN
# 19  C0035110  C0035110         3          1       132  25633276         RQ
# 20  C0035110  C0035110         3          1       132  25633276         SY
# 21  C0543467  C0023087        11          0       155  25633276         RO
# 22  C0009566  C1955856         2          0       156  25633276   No Label
# 23  C0003873  C0035648        14          2       166  25633276         RO
# 24  C0003873  C0004057         3          2       166  25633276         RO
# 25  C0006826  C0035648         7          0       166  25633276         RO
# 26  C1955856  C0029473         4          0       176  25633276         RQ
# 27  C0027497  C0231218         2          0       198  25633276         RO
# 28  C0231218  C0015672         2          0       198  25633276         RO
# 29  C0009566  C0021149         3          0       201  25633276   No Label
# 30  C0043240  C0043240         3          0       206  25633276         SY
# 31  C0043240  C0043240         3          0       206  25633276         RQ
# 32  C0029473  C1955856        13          1       214  25633276         RQ
# 33  C0392756  C0206174         5          0       215  25633276   No Label
# 34  C0020883  C0023985        10          1       217  25633276         RN
# 35  C0020883  C0023985        10          1       217  25633276        CHD
#
#     Label Id                                   Sentence Indexed
# 0          0  [CLS] This is a <e1>review</e1> of the relevan...
# 1          7  [CLS]  <e1>retrospective</e1> and <e2>prospect...
# 2          4  [CLS] Retrospective and prospective articles s...
# 3          4  [CLS] Retrospective and prospective articles s...
# 4          1  [CLS] Some of the most prevalent <e1>trend</e1...
# 5          4  [CLS] The most feared and devastating complica...
# 6          0  [CLS] Conversely, a <e1>retrospective analysis...
# 7          0  [CLS] A systematic review of <e1>five</e1> non...
# 8          0  [CLS] It should be noted that the AL rate in t...
# 9          7  [CLS] Seven patients in the <e1>test arm</e1> ...
# 10         3  [CLS] While mechanical and <e1>endoscopic test...
# 11         0  [CLS] Large <e1>rct</e1> of microperfusion tec...
# 12         1  [CLS] Large RCTs of <e1>microperfusion techniq...
# 13         0  [CLS] showed that among stage 2 rectal cancer ...
# 14         0  [CLS]  <e1>swedish</e1><e2>Matthiessen et al.<...
# 15         4  [CLS]  <e1>sepsis</e1><e2>septic shock</e2> ie...
# 16         8  [CLS]  <e1>sepsis</e1><e2>septic shock</e2> ie...
# 17         4  [CLS]  <e1>sepsis</e1><e2>septic shock</e2> Th...
# 18         8  [CLS]  <e1>sepsis</e1><e2>septic shock</e2> Th...
# 19         5  [CLS]  <e1>reoperate</e1><e2>reoperation</e2> ...
# 20         2  [CLS]  <e1>reoperate</e1><e2>reoperation</e2> ...
# 21         4  [CLS]  <e1>operation</e1><e2>meticulous surgic...
# 22         0  [CLS]  <e1>complication</e1><e2>stoma range</e...
# 23         4  [CLS]  <e1>rheumatoid arthritis</e1><e2>risk f...
# 24         4  [CLS]  <e1>rheumatoid arthritis</e1><e2>asa</e...
# 25         4  [CLS]  <e1>cancer</e1><e2>risk factor</e2> Pro...
# 26         5  [CLS]  <e1>stomal site</e1><e2>wound ostomy</e...
# 27         4  [CLS]  <e1>nausea</e1><e2>malaise</e2> Parasto...
# 28         4  [CLS]  <e1>malaise</e1><e2>fatigue</e2> Parast...
# 29         0  [CLS]  <e1>complication</e1><e2>incidence</e2>...
# 30         2  [CLS]  <e1>local repair</e1><e2>repair</e2> a ...
# 31         5  [CLS]  <e1>local repair</e1><e2>repair</e2> a ...
# 32         5  [CLS]  <e1>wound ostomy</e1><e2>stoma</e2> Fou...
# 33         0  [CLS]  <e1>reduce</e1><e2>hospital cost</e2> B...
# 34         8  [CLS]  <e1>ileostomy</e1><e2>loop ileostomy</e...
# 35         9  [CLS]  <e1>ileostomy</e1><e2>loop ileostomy</e...
